# %% [markdown]
# # 加载数据集

# %%
from datasets import load_dataset
import jieba
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.metrics import ndcg_score

# %%
data = load_dataset('C-MTEB/DuRetrieval')
qrels = load_dataset('C-MTEB/DuRetrieval-qrels')

# %%
data
# Out:
# DatasetDict({
#     corpus: Dataset({
#         features: ['id', 'text'],
#         num_rows: 100001
#     })
#     queries: Dataset({
#         features: ['id', 'text'],
#         num_rows: 2000
#     })
# })

# %%
qrels
# Out:
# DatasetDict({
#     dev: Dataset({
#         features: ['qid', 'pid', 'score'],
#         num_rows: 9839
#     })
# })

# %%
qrels_pd = pd.DataFrame(qrels['dev'])
qrels_dict = qrels_pd.groupby('qid')['pid'].apply(list).to_dict()
qrels_dict
# Out:
# {'0014452c4edd2dee9b40b0f78bfaf8e4': ['a2635150b429b5f2e7f6a19161e5cd48',
#   '6b1ab3ee329e26780b85c6b9d7a6802c',
#   '94575ac389d80de88128c3f1788d395b',
#   '1c37837640973fbe28c1035fb7dcac61',
#   '2e23a09ebd69974932d653b3d39b31c7',
#   '373bbf909da9704d2973f2b0411cedf1',
#   '2d9f2b19a60b45ef24e4b265bbb05847'],
#  '001a1445571eb22b00b899f7a431988d': ['43cf0e73e8f92c2ffa3dbaf2cd718176',
#   '30d02ef813942ae81da43dbaf6edd6ed',
#   '03712065d5cc89855c6d23ed78163336',
#   '966a3ea48c601714703ed795115f3961',
#   '4b187e8405c95fb421999286ab7122c9',
#   'a4dd3b8b9b3549010bcb595af06de3fd',
#   'dec02b84a98cea8f8c3c032816c6ddd1'],
#  '002da0e5525d4841658b3b57a1c04b9b': ['1b4d333e09d3265b2e7fc94c10be1c55',
#   '9441f87127c3d70449e6d4a87cb6eec1',
#   '56f3cb86e5dece094fedcbdfba7b79ea',
#   '7f09c13d7ca6e7e0d4a63e5add5e7388'],
#  '002dd675c4bdacea74137639dd4146b8': ['f543979ffff9df4c017b7c9f64fac57a',
#   '995adfe0f5bcd3ba84451f0ad5f3a642',
#   '4359a7cb8654246f0ac016ffd8d8c33c',
#   '142d6b6595be6795024ca6a512daf31a',
#   '1d95ae029b0a9ec2b6e437d035c855f6'],
#  '0039e1f241a4280d6480124d676c0c86': ['e3eb6cc4f47a602004134f753f2fd8ad',
#   '45d464e87ebc1febd9d73d7093630149',
#   'e470efeae7c8306b7d9bf2e7f724cadb',
#   '5726f6d65dd3b89d005ccae53e18f118',
#   '9ea9cb8d6fa0a5201239b359bac58dbd',
#   'bd2ab27987bc635cda9d9b2b166fe46b'],
#  '00494c413574884600838e13fc4d43fd': ['d6d288d43745b51639332b0fb218f3ec',
#   '2013fc7bea020db56670cc8c764aa813',
#   'adff6864e4ac66115d0544603a94f140'],
#  '004bff709533c4ed717584227304f4e9': ['46f5d0c4e86a52e0bea4c2f1cc014b43',
#   '245afdf888bd9e54d25bc43ab3df22d7',
#   'a261e655984adac3a93828f8cf526e78',
#   'f6a2c3f345f4f3584d3d9814d082e358',
#   '5f6540d828494ddf49fadeed1e8f2892'],
#  '006806b2416cf439b8131aabd17a3f89': ['8ecef583475e2d7006ecfec12cbc2d80',
#   'f8201a4aba5f4d71bef5a454d4ebdd7b',
#   '62ac90a462ee0071a6329558f1283e55'],
#  '0072b0c0d45d126cdc21c394d395f54c': ['da85eda9ccf2eab0780eab749665b824',
#   'a6fe496cbb609b89a9f897721752c5e8',
#   '2c1b8a9eb92812ddb56f19cc797ef139',
#   'dd13384a22dbf2d6e3615bb49bdd212a',
#   '4c26cbc1fa635734212d0222f7e7445b',
#   '69cf31eae0d229cabca90c3affc07c2e',
#   'e9686575dcfb3d0e242cf410dfe216be'],
#  '00a969b83d0bda551c8ba5ef9ad9d3e8': ['6dddded28d2d08edae67d48749bdc125'],
#  '00b502d6ccdf2b4d7da8ddb7573516f2': ['e9c56503f7a60b1c16cb3ccd9dce2503',
#   '10bc40f9bbd0641942855a58b67f4a4c',
#   '29a4e2f5381a47ddc109e6829fe20780',
#   'f486f22aadb10b065118fee869156602',
#   '86632c311356f6851d06d7d86e91082a',
#   '2989b681079670aaff79d936d3ffc9aa',
#   '23f17009fef134b43b03dc3dbd5ddd2c'],
#  '00e1519ac09a1f8eeaad38fb95730028': ['faccbf99d40e34494ecd09c354fdc710',
#   'da7bc847dfebe0b3788bbae4e22da81e',
#   'b864b8d078810bfd934f58936f8b74a2'],
#  '00e704e0313fa227ab121272edfebe9a': ['074cc7b6c469602c604a96da62c99437',
#   '154bab3818952ed52bbfdc0cc3f38c3d',
#   '4b478fbab89777c1e53069b2daba6d94'],
#  '00e790f7446f20fd2abc58f2c112a5fc': ['5400f6ad689cffdd37419f4c60eef0d4',
#   'c3157cac50f49644a975210a255fe0ee'],
#  '00fde2506c580acfef17e82c385d455e': ['38c5788a3283a1b3ffd300a91cf1203d',
#   '76339dba72bc9d2fd7f193cf80a1fb69'],
#  '014a55bfce60800ddcb6800942c9a533': ['939cf5864eb21a957917b369e6d5daff',
#   '897e850396bfd5f833417b4931088e12',
#   'cccb7e3209c083c970cb723f236e0b5e'],
#  '014d3cfc7c3b409339eb2a389ba9145b': ['1779595f26855606edbd613cf0686f69',
#   'dd89c53c98535defdd61332555761788',
#   'b52818009038826412469afca29f1201',
#   '41f09b9649033a760c4057936e04ebd0',
#   '7f07d54111598045de134aa5a37a2e4c',
#   '34083c5df45ecf72d6c00236a318c48a'],
#  '01612355fc6783987b115966a5214402': ['cff3b06cdc7268c4ab66cce6eb6c3977',
#   'c0d1160279f7050237c5edbc7673ba99',
#   'aaeb11a49c62acd90f05a33b19c9aeb7',
#   'e2bc9e633efd6e4d17961d3b66586cce'],
#  '0177377a7930748325ae42e580af3ea9': ['bb7f52d6f51da42a975e838c79d90a14',
#   '47e178cfc61668d8edc997c8b51c7244',
#   'e78bfb12fd3aba811ac297d0c79ffb64',
#   '71f01a88427a977fe99ef119b78e0ef4',
#   'e74e9f59c39f28be6c5cc8b8b49707d1',
#   'b192976584a1e2a99e4d90bd06fa5ba2',
#   '63cad1bc2ade000e94d450acc7e5ca6f',
#   'c88278e9563d0f29926f6959e6dc7033',
#   '5485ab585e73670593aa83f945d58e7f',
#   'e040d196e3256f9cdc17fa83ae188a99',
#   'f5a84bfe0551483aec6257ae21237d1d',
#   '4bdbec85ef1a4ec0e46c99aafddf55e3',
#   'b0741f65e0d9834d4b023ff52059be11'],
#  '018fe452a79c84cf08f7fa69a0b31503': ['f064dd0ebc07c6d0da7d21a37ea3dda5'],
#  '01e9fe7df0e2f988e90efa4561a993fe': ['cd28ef8904ba1e295cf8bdb098894439',
#   'cbac8ca7f93e900fe9336a47f071b413',
#   '8419d9cab6b82cc7d7188d1f2ecec792',
#   '1433717d3c677b7ecffcafa85e219033',
#   'aa8b4267ef1e67ec54456ea01cfc39e2',
#   'dcef9b6abcc3d0be45948347642ad204'],
#  '0215eabd32cf8108d35adb4dd94b0bc4': ['45f579557cc75fb18a266827dfc63c3a',
#   '9b7f4c02db2bf68d99845d7d56f9d9bf'],
#  '02293e32393b1db39080ad78b534eaf9': ['dde786b2dc93e9280ec000b062dacac5',
#   'b0e1cac55f652089ab3739f81d5ea883',
#   '729e145fa4638996a4da76e3d54eabf9',
#   '95aec13a49cfb4b48c288ca84f6bf427',
#   '8d9d1c72f03c5525900cacc0516511b4',
#   '8fcec7296c4d96d738d99755edc2b0f8'],
#  '026265e030fe07cc658ad83a87e1f21b': ['c8f33845cd1c9ac4c516b6a623a7aa7b',
#   'a67d0be022941e32acac7f70b3cb23d8',
#   'a8acf1ebeab20ce28982e6f0fb7df826',
#   '97e55fbd2201ee8776a8cd65a7e0e504',
#   '592edabccb8c846893af76417a18b990'],
#  '0277b0f123d00e9b035e4d7692ae2110': ['893c8cdae29969abff8ee2094b34352f',
#   '5c5f9e44c83ccc413ff86d299218615f',
#   'fe0944a55fa892d435426cdecd05c88c',
#   'df5b3938d2fd567c2ed6945221e97b9c',
#   '6e4426b5aa5e6e44a61670b22cf72bc7',
#   '35007e23c5593574660472dbaa68cc35'],
#  '02956090b66d0ec7a8623638e3cbb49d': ['e0a9e8c0ea42ca9676c707af65481038',
#   '564bce17adea81f5eb6c0e6fb0e504ed',
#   '034059bc6c3cf4f9f2724a7df9b8face',
#   '60cafbd24a791c7a92470e4f770e8c56',
#   '9dd15afa35e68258354e3afc038b881f'],
#  '02be8b98ed283fe7451b116ac489b0d3': ['16c4fbd4d8474698671eee44ab865b3a',
#   'b8a9aa6408c5e565898d07bbefed6908',
#   '8967d49d3dee01f7bf9969258704dcea',
#   '7627531e4e37c37ec164e32e5cb7da15'],
#  '0327f9bff7431ff191dcadf0066ede8a': ['872c9955561a8a95d217f3334811b80e',
#   '04e7677e0f1a29481e5b8fd5b22a800a'],
#  '035158619e97c988982b612bf339cab7': ['ac85011bc2097401a6057303a0f71c84',
#   '814cb433a34bc2b025d70be873add005',
#   '0ad3d854dce27994e57c42cc27a60532',
#   '4e72d32c40bb80fa98d75bb00a570e7a',
#   '78c30d3e3bee7874be9fb6c02e845def',
#   '70c0a9c11ec1371468879e7de048d151'],
#  '0369b0fed917acd0ae9ae36d7efe4cd4': ['efcb87d04c6980536e9d37d6c62ba847',
#   '381254b5b560f2c585c14e537d1d6095'],
#  '038c9c614e615ce8008d3e8612888903': ['bdc194786f8c56c9acc3ea2c4cae50a9',
#   'cfe8ad24d0e948bf31ff275b231c63bf',
#   '8b50ac2fff48a9d0cb6e0df594e679fd',
#   '75bfc300dd26a0236ccf1763750db048',
#   '3f201ca566a8d0b5020252d5350b72bf',
#   '3c53b5d454c685c467c78d7656ce8d48',
#   '0ff322d9c3acefd7f69d89a6bc238381',
#   'f3be05c999dd1adf8fdd10264cd0efe7'],
#  '03ad3125bdca1c7433a1d02eed7225a2': ['e09292d0da6b75a63d03f046ca05b599',
#   '7d52656d3c757e6eb7692e61241304f5'],
#  '03d3b95808c00e7241dbb83d7426f8ce': ['f708763c1b54288cc51c0dea2609a820',
#   'a12ec8fcfc724fd0b1d1e2ff85ef7946',
#   '099d24dc17583af38620a120b1524e19',
#   '94181c93d97361045a0e6f5e64c5145e',
#   '1fc9a05f9e337d0f3611a424d7d5bc45',
#   'a9e0380e7df7adc8a8027580bca9b32e'],
#  '03d6ed920dc6a70fee3cc88d0f59566a': ['d5f9ad2060f85e468ad4a59c57d7a3db',
#   'a6bdc14f95116dc1e123302e4400ec88',
#   'e6520fe445d7107030e685cb5674532e',
#   'ba7ac3880d84d2b357d7cdb86c481f26',
#   'bb0c0b0fb62488dfade756251b841065',
#   'f4f0eb035e672cf971c028f7914546dd'],
#  '03da5de4b0562710dc3a4d65ae7a9261': ['f951419a555eb0bf73e0c1b0d55017f0',
#   '5f98267798871390f1dbdc8692e68715',
#   '937d38609d87a0cc808348035bbc9916',
#   '4a82c2494038f89276c39dacb5086ba7',
#   '6ae0cd70171761fa11acee782fcc8956',
#   '0d6ca6174dfaad13c057ffcf62401afc',
#   '3bf7ef8450fa46a0ea78efe6fce9da7c'],
#  '03f5626cacc9d08b99bb1dfa39f031f7': ['c94ec0b623d4ce1573ba322a399f0ea4',
#   '2fd110ee7041d3dfc2546ed0efbc16f4',
#   '8dd22c7c1fa262dcca73a2292c636695',
#   '4d172738732646a61751a3efacfbbed4',
#   '7d214a46986293e668acd547495fc107'],
#  '040dfb36aa84e4de96c69db72a27edf7': ['4ac14d2d833b7e5776401f9dad5fe1ff',
#   'd64f83af2e2000f28647a56f316b64dc',
#   'a57125dbc02679edbb07c57e4e095d3d',
#   '14b9933dd905ed839ba178f8c2140e13',
#   'a90beba44ab41a3f572680cb4faff1d8',
#   'dc0d5d9bff304890b2dd8f264cfbcffa',
#   '2123ed95c259433652a2bc8b1edaeda2',
#   '08fd128772ab4d0fd7ceb24ab769f3a0',
#   'b97f613949fbb1e1cb659f9d7abebec3',
#   '7bcc7bc27358b32cd31ee0902139c985',
#   'cac502758e1bb4af7902e7d25640f017'],
#  '04338e253fbac4ad4ac19e1996c1dfde': ['e7bbb1d1622feda9d77b983e32a87473',
#   '3573e6ae0deef59d96906c1a4d06b67b',
#   'd4b428ea38c01c6e88b7f657032e3709',
#   'f5ae984126a8fb3c0673ba8ecf777174',
#   '3db5e152ad3fd07bc08c5e28b0aecce4',
#   '475ef532359c4a16da45305f22bcb3de'],
#  '046cf329bb8fe4679a6726f4db0ee026': ['e6012b52425032c4974c311d11017dfa',
#   'd8c48bc8f3b18270b83df982446bee52',
#   '8b2d90d9bd5ad9a3eccca47fe46e800b'],
#  '046f45c575c805b53ba47cb02078e439': ['3f047e34d691341ed1bca153e191b959',
#   '509b33e1b146a9c4203222d9ff023286',
#   '7c4796918ff87bad05d6a63e8d1b59da',
#   'a11fc975884f83f81dfdbb9a51dcc74a',
#   'e97daa361de089b74e38b501f3793418'],
#  '0470db5f2656567969f487bd6a870cc4': ['b272df0fd68cf1f5ba8dfa1dd9b426f2',
#   'a73a7712c1d31a75fe99fdc859f6aadb',
#   'a7663a7c52d54f03a3bbc5faed18848f',
#   '7994e8345702856c701f77f9280dd765'],
#  '04a5e130352a7ebf77556391d3d188ed': ['c71cef5e513b3f43ac77a772b0937edf',
#   'b58abb3e89128cfbd61e885610e4e93e',
#   'f7750c4e3d45b18655b5e3e58e37cb55',
#   'e0c73dd49feafc2f5040a7fe4649ccba',
#   '729cf0a3edb4ad2e84402044cb233a54',
#   '8d23b2bdebe3d6b3c5506e0bab1bb2d8'],
#  '04f581b6ddb51f959087992f76e40075': ['4db737c495a7a5dfd76a24115e10a6bb',
#   '48c16645b7b3fb70425bd282250445d4'],
#  '0525cf1756bee5969e9474f437b176a2': ['948f1281f792676e5e8e810923b82d4d',
#   '1044fe00171cc353793c8a20c796aa5a',
#   '46d689fc427696b537651bc1f13cfd91',
#   '5f961b3dcd4e4fe5d11672da3f1c740b',
#   '175b03d5e563a158fd2ff195d8e84eba'],
#  '0554e12bf23d53cf71785eb77e5812b6': ['335cc3cd308949975ee9dc85673a5d4a',
#   '72f6892d3f7ecfdabb86eccb30a4f675',
#   'ec49ffbe6bacc9e4680401e0b5998e3d',
#   'a5a4ab4857e87662bda2293fae54a6fc'],
#  '0559f960c22ec575a64f869bd1fdc026': ['7f99b2381fe58616acd0c29155a96c1e',
#   'd3a8f61ecd58e0127b69a4b90673d37e',
#   'd947c749e66ab854d3c55b1f0e2bdf22'],
#  '055a96a5e1ff58ad0bfeeca404775e6d': ['4087aecc4ec743b6d9c20c1f6049a38a'],
#  '0571474cc8ae3e213321ac42e33edd82': ['4ab1cb3dce9817421e7184085c47225e',
#   'e046a047486621e6754ca525d23b97c7',
#   'c4d7472e6af3e9cb2a2166a75a17ae41',
#   '7ea9594e25453561b4a8b24b031ca937',
#   'c3a43c692a8968b290acaddb024989e9',
#   '0b0d92985093d9cad872f089c3ba1329'],
#  '057ddbc79104890d4dfe2b6126650d78': ['4b62a7c04ff78234ec6321ee156035e8',
#   'ae837d57ea82fbf76b4b77d2ed63a7eb',
#   'aa6bade6e7420feed6ff6fd429d0ab2e',
#   '88d1f954a68efd38d18bd518584b5e01',
#   'ac6d2782207c0a1d05683b2f6edb374b',
#   '9efb1947fbaa26360396afd7de817c61',
#   '24cfa619042a9d7d7626f8f1b4165d0f',
#   '136c3c1c7ff38c91c122df71b5b02fa9',
#   'f7ecd64d0533e29b3511b133ec35f919',
#   '11765dc626d5c498d983e670a1e391b2',
#   '5fa2aade7821d04bb5e84d31ca8ae875',
#   '7263ef0df9d22aa11435143c19a50a43',
#   'b7f1d42eb074739018a71230ccdc2246'],
#  '05e2a1662e35e9515a61e598260d096a': ['ac7ca0e59fac3c9a9d8d88080b00c1b1',
#   '5d87ac7d9807e358f754b6383b803a48',
#   'ca30cff868e0855e109c785b13088d0e',
#   'c51717b6df6395b660f8b6654a6d0f44',
#   '4584928fc9dff430330a5f278533906a',
#   '97b9fc4123c690887eef188fc68db61a'],
#  '05fc44c52ab6bd5b862e4f94e54bec3a': ['b5510b364cd971d314ebfa71735943bb',
#   'f62158fa718a2fb50fe2743b240c96e7',
#   '06c3cfcad42471ccc4632e7f72334cff',
#   '77afb78934aab65e3b3015183a02808d',
#   '7350d687627994c20b1ecf371564d10f',
#   '080148b69912febaeb0ab9252d26b033'],
#  '063b0abb31e97d39ac99f729ce89d2d5': ['8fd43d44fa48b88e7f277fcb00c8f82d',
#   '2f23723781848dcd85ecb7ce7588655c',
#   '2c24682636a358144fc1f6b78ca2862a'],
#  '06e462478c3f7780d2beb65ecd19314b': ['4a8739e5bee9330fcfcadedd35c25385',
#   '955fe7197f30b327924d6a5219ac7746',
#   '83c347b98ae15d702f6fc398d6049657',
#   '61e14f7143be3a6d8320f3ecde6d0a36',
#   'a9609a5a1c9bf9d92faaae7205a9b364',
#   '9a5c824b8b28d1f863606881c60ea14a'],
#  '06ea4b584d285914aef3ffe5cb56c8a4': ['2989b681079670aaff79d936d3ffc9aa',
#   '867e439bc23a571f2688be08bc4b1d0c',
#   'cc82dd74c15e528e9b5bffe9264c293c',
#   'c4298b75aa87280756517e042a5028c9',
#   '4806acef33a9b62279fa5ebcb546218f',
#   'ab9be5e6135136ee493331a1b7112c8c'],
#  '06f82a708d4fd16e6f7f42e03c5f03f2': ['429cab21112a78e5cb8e0899995016c8',
#   '7cc82f942ddf8e5299f58d037f835787',
#   '544300620672a910b544a15e97345ded',
#   '8681f02ae0bcf0219462640082b44189',
#   '833c9486cfcac3c830af3396bcc09655',
#   '9238fe3af80a83ae3178be8fd255c439'],
#  '070741eb98af77fed41c4d4b2d266375': ['90c44412384eeace5f87bd407671238b',
#   '5fe8412821d6a987665b3dacf0117d3c',
#   'c344e7af31204247699f2ce5c8e8c7d7',
#   '695bdd2825e2b42f8f49dcaf9d117ee3',
#   'f9f04d8db048803cf3435c2c11d12cfe',
#   'cd1e9f4d85723de86c3be72f26dd8494',
#   'e8a582ddb95403cda8ae7d81aff4c919'],
#  '07219e990d17b88b51e77276da0f500b': ['d77223c1f4546dbda33e02b1097bd6cd',
#   '4aa1b1477efbe926b05797bba0fd8fd6',
#   '7d31b1f280243fa034634e75738069d1',
#   'dbed5ecfb10aa53f08430c04587c1dca'],
#  '0725d30f9b4e5e712cc2dbf6000e31e2': ['4787b563ce01fea839c3b1366264f4e8',
#   'fb054fa1f99037375418278e3a19d525',
#   'f7ae2b30b3c033f2f81a7f6d0d76081b'],
#  '072a2dee3d6cb400de54b163f5468283': ['6984679152fd0f1cecf88077893b00dc',
#   '3b3e563fe38481bfe429e0cda457749e',
#   '5f79955ebeb15af8346a4de82ecdf977',
#   '6cc9b3f61f3745ca8be43663780f3734',
#   '572b4802edf109ff94a5090f703dd10f',
#   'fd78bc13bdf35c1f0309368ff49d3f16'],
#  '07430081cb761a84518da9de7c488f40': ['3787582df38200d8acfa670bd3fe034a',
#   '3ed67b6d91a542844041ac8eae8b7d1a',
#   'ccfcd1a39148092c9c08b7048a9b7536',
#   '479ad4cb3e0015f07012cc8d83b20895',
#   '533ff4426bbc307ebf2164923dba16bb',
#   '42e2914cc218b72befbd62dac967f9d4',
#   '0847ea2c13c60e9d707dec11690c3104'],
#  '07731e1ccf6fb54614379a370605e92d': ['24b8caf512cf1f527fa547d699f48e35',
#   'ae561815e3013d4c782a6791f7d5f673',
#   '84430b08d39685557b905c541e12180e',
#   '56c339d47f3c7397b5c86ddde7f6b763',
#   '8a4fab8461d4f788906800e59e59b0df',
#   '64ba33d73c6185770a5e2792d4bf4d94',
#   'e857b51be3649287dbe3f7d821233f4b'],
#  '0779edfe05c9e704b00638c1be1e5744': ['7d1a15a1b861a375b97799cc7fed4eb7',
#   'aeffed150a2505d337f1f81862eb798b',
#   '0a0b6dcd2db7cbe310d80cb9e50432a8',
#   '491d275a1d19b59ca7258e4001fbddb7',
#   'e46c8d96dabfb28f44d9e1530bec5be7',
#   'b737ca56df402beb92f1849b6e22d96c',
#   '593094ae8e918601ad963465a116951f',
#   '4dbac970ae2828405d845ba127de5871',
#   '5eaa158e1c2f9aba780f72cfdc698f0f',
#   'a398dda305d078cc421c4380d6b4a251',
#   'b4103a0360c59a2fe07ecfd4ec37f053',
#   '651a8641887c97c3476efd5fbf811ed5',
#   'a27a731740af0b4fe02c41e6455d9811',
#   'c2c17e4d1a3a2e84ce925d1b073f98eb',
#   '570869d345915e6cd9ff9a3f900fb846',
#   '04657cd1e110b6bceefa22cb088fe451',
#   'bee1a2f00512f93156b21c08054bee86',
#   '4544ede4e50b68169761155b8feb857d',
#   'b0339968aa3c6a0ed660c151d0adf8f7',
#   '79ae9524247c387c2b600e3985bcdf46',
#   'de020d006262089d87e79c12a8af17fb'],
#  '07bb4ebe476e2e27cf741863d3404411': ['899ecabc20c5824728e69b445d89759d',
#   '9c141263297cf21be346869f4c1b312b',
#   '950b8b4af739e0515d7139bcf02df105',
#   '128fc1132f6e039ecea1c362e7b59b4c',
#   'dd2759f6a3aa60a54a61884f482eba66'],
#  '0825f43f1afdf532c2ea35a801ce7a86': ['2f733b2342965fb91322a4b0be6b4c44',
#   '7905b3a697429e745e8a92d2c26db781'],
#  '08295e0f652004eb7a013064ef09c64d': ['0c3d7de5bafbbe588109bb2869adea32',
#   '6ca31cd391c209ef457047210ad818a1',
#   'c4a6993db8ba17f51a1fe0afef7c7f60'],
#  '083dee5ec8adb17ce0dae09e424a1823': ['1e21839bd69e304fd515fc4cc660eff5',
#   'b5c3d73051a48289712111bed2a16890'],
#  '086bcf6f040ddc99d6cd58b2cca29b58': ['3089261b9929a9957900a11fe20f1ba2',
#   '5067f2b5aec4da46f4672c9b3d836f0c'],
#  '089f4aa941bb6594f49feda2a74cf9cd': ['f461f25b3d827b9a5343b1aa85194dff',
#   '0cde91feed026ee3d10c35701e3447e7',
#   'ddfe53930cb706089c5247c57218d072',
#   '4bc0c5095a2e51ac60e9f7c4ca7166ee',
#   '6ece2eab509e1fdc776152c617d6a1e7'],
#  '08a0172c2405d2935f501d173232f9db': ['d3863dcc1d8ac45ee554a332e068337e',
#   '553888f77b528f1a7219cb547a1f9b3c',
#   '71e682783e711945bc71678f70b3bf2b',
#   'af2a2c2caf291e81f8378a169ee39da4'],
#  '08a60536c7d0436f2bd17d0a143b3fa7': ['15bfd8f27282b86a42012c6d381bf2c9',
#   '11408500945557c5b13637fd58a73eca',
#   '0aaea55312e36ee57aedf6750edc16fb',
#   '672052189d81afa102dc60ec3cbe3400',
#   '37c0fb20538f933c6389f05252a445db',
#   'afa7f7649a5018fe32e374538aab4456'],
#  '08e90e05912094a182420c9d05b2a2c9': ['317b7c24734d3ec7b502c4d5cfdf7fa1',
#   'a473093667dba43c1e8128033d7b3a75',
#   '1325fb6724c90a940e3e537e64fa43d6',
#   'bd61bb87a1f835fc5c1379c16a969495',
#   'b17a4f9ce1f6f4bdf237d8fe0a34ddd1',
#   'ccb9d2fa6b05c89434c9763d8ea0c185',
#   '21e316df631fd1ad7f39d1dd59cdb9ef'],
#  '08ed5dd3b40b6043b2737cd81b8ccb07': ['6b4ff782d863977dacb694e7c9c8c313'],
#  '08fb814454bfb16370d7f0372bf3dbdd': ['a1c4b23d42b18bbbefc92ba120bceeed',
#   'b305b6abe9d9555b9b9e2b40feaff0bd'],
#  '092085d95f2174c5795dc9169e94da5b': ['5abf9e828356f897d9f381bc1737a8a2',
#   '4578b91adb22a88703c92036882929b1',
#   'f91c5523ad752219141c261133fac73d',
#   '1e89e543cc7168b0417b523f246d2e93',
#   'cc238c7f82882cffe5f52fc70f2c58ab',
#   'c8b5d8e8407f8b78aa6da23c8f4fb043'],
#  '092b7a3f77716be5e5c105b8fa998d5e': ['44423cb39b62f919c85af6c97ed42b49',
#   '08146efadc3c3c2bfb7300d9712b2b14'],
#  '09307d8fd0f0e08ff86e1e15e7da1f7d': ['7d23853089d0371c285d77f16a8b2000',
#   'feb4a7972e20b2952bf4a09872aa337a',
#   '734a7ae78c3ee3007175fbb8e6d1cea4',
#   'dc1b9252037c5fbdc38995d58575ce31',
#   '9bfa81263c333f6137e3d345e594b82c',
#   '79f78fe92ae906842310aa49beb84de4'],
#  '09bcb358a2aaf6cb61c824b297bad08e': ['e7a61a111558cf772b844029e695bf46',
#   '304e4f2bfba924509ebe3ec47b2bc73d',
#   '924a62c502def332b079629c7c35920c'],
#  '09bfde0530745af3496e0fd4fa1f5456': ['ff8b9dd013222cb9f43391c790a29dd9',
#   '013ab889e20893fecf745909bfa5a4a4',
#   '823314c731cbad719d71564a7fb2dae3',
#   'ac43ae0caec7ab1ba77d00d9387fd116',
#   'f056f28dd07865a3d15e823aebe87f76'],
#  '09fd7144c9793ebed825542135754fec': ['120134637f37a943258a1ecc5e5cc322'],
#  '0a3acbf7afae9e56a811eaf13a10c500': ['8387f68176d36021234f70ab475410db',
#   '2677df3ba060f7d34b01d0a1d6b1af36'],
#  '0a427cb6c8f3d4596620ae8aa788f521': ['a163e676d4aacb81b61cafb02bfce966',
#   '854073b166651c4bcd81e77327796635',
#   'fa8246a79b7027db0b4fe0d9e7b0ca54'],
#  '0a6eb21dcd9a657717a9bb7ca014ddd6': ['f33df413af044fdb091d80d9d0f3070a',
#   '33f382629092a00e09f7fd949dd4d3e1'],
#  '0ad1869857192361bb90b89bd6850134': ['b9d1e445bbe953238e5a5bbbeed43fe7',
#   'f61d602eeede22db565095553bda45c0',
#   '0ed915612e9b711071760597205d942a'],
#  '0ad6e74c4cb78faecf1949341e835516': ['88c531bb6a2f6b228b74583a24e1b33c',
#   '3480807f939151efeaac993c5845d261',
#   'd99db846e478bf6f94ec254e6e65a4ed',
#   '8de035399e4f0b1ff5151d6dfa02abb2',
#   '7e806fb36878f6513339a11de3272ba6',
#   '95cd8d74c4382e6b4972f8b811befb66',
#   '04134cbcad7846ee241ebc6f7b47f923',
#   '59a29b146fcbe3ce1ed7a221bfcdc060',
#   'eb4dfb58b9f4240a95d9c644c5b15059'],
#  '0af58f6ac45110b82faa7b334ee8c920': ['258cdfffb6725ce7368a2730ff6dc4eb',
#   '011b31b3fe16797ea85524975da89eb1',
#   'abd8e0d5ed9254b5593ebae714649675'],
#  '0b237fb521c54d0e4fc21ad7edcebc8a': ['cbd9abc47095fb26fd58479cfe3163dd',
#   'a01f0ba7e19abe71d5176dc6f2c7c56c',
#   '2d029f52e38163f502a5e0bcd85a0bde',
#   '4225b23088941b4925841a751eb804e6',
#   'ce7e0fbe3b8efc8edf1f77f2e96c7883',
#   '7600cb565fe5645c24d0b22641daba63',
#   'b448c25cff3ed2aa2f0975a341d68306'],
#  '0b32feb405519313566b3735e983a253': ['120301125ae69d8f39f721781b63ba33',
#   '6799ff45e320260840948903e9156b6e',
#   '71e2b83be85bbf5f1de8e724cae8c6eb',
#   '76bbe48bbe3fe40a2c1fe43ece816330',
#   '029af57012dbb9f13af2cfdfd348fc79'],
#  '0b75cf6414b8c467909e94f85d15c37c': ['18e18d8aad3fbec0b5ba31077631161f'],
#  '0b8cc5b56e6bdfb9476606c79f04ea9d': ['c98f70e4413145861019943f3b108b82',
#   'e7f9a6917a35882190a85c7e7d07a789'],
#  '0b8e4a325606907b4338dd8b471e2033': ['f2eb35a21f39b45b21f47ff1d14528a9',
#   '2ebf92d980a91f4741034d35c1a934cc',
#   '3a873521ca61331eaab1e1932cfc1a18',
#   '55562888ae557ef0e60613c39c8b7e6a',
#   'd20d82d03a126119358961bdf5c78fa1',
#   '91afa80f931a5ae1dd199171f50d5cad'],
#  '0ba41952beb2fefd07090c84367efd8c': ['ed8a33bd1334ca9e1b2bcc639f6f65bc',
#   'fe5d72ba063e2462461a15972c1251e7',
#   '6c674211a473764fd5c6981e017117bd'],
#  '0bce40f8d168653d6574d64653573bb8': ['45b0041f6721ad7bd14bd2a3e692d2af',
#   '96d4f196b2c6675edee49a3bacca676a',
#   '392b4e0ae1c4e89fcafe3b4ee88545c7',
#   '39a07bb00c9461302161d894086d2438',
#   'aeea26a1fb26ee864bcd2c3c9a3cd149',
#   '82a0b6b24e5c9538625ea273181b06ab'],
#  '0bea51f1d4082c86b01e8b601719a1aa': ['ea1176269cda13c34e1c294dba5c14a3',
#   '959c9912e3ac568df4fee1bb18b12366',
#   'cd2f97690f0ae81ec260a0946bddb485',
#   '4c50bd9a0a469093c32b767385d844ea',
#   '4461d6fe3b022863dd9f7a1435ebec62'],
#  '0c0435f3c88fd735b41d8c3a36b8a2c8': ['473117e2534c74a2c19068c1310dd00f',
#   'bebad89c6e6160db7efa3fc277bda6e5',
#   'da39f67ee5bf34e43b9c129150900a56',
#   'a9c10a4bd334181fb750d8d95a35b88b'],
#  '0c86344fddad3c80e797541d26b7a592': ['ed940a324867a9dbe7e955889988cfa3',
#   '6a436205b42b263b2cce514dae89199b',
#   '06c0e1ef4a22ef8302f9e8995e0f5b71',
#   '7a849f89b268a302ce61997b385c0aa8',
#   'ab1f9d6e09cf36c7e22189e798e37f8a',
#   'ea4832a9c7e24a69bfd21d1274e0a6c2'],
#  '0c96d174496c3628d45e7fed5afe397c': ['da8349a22ca2e02c9b69089fda3d4230',
#   'b86d2777328b7ab2e8c0c367252747d6',
#   'b54ea39d6597f83f735cd843f0c292ae',
#   '7dd6a1a81507e8c9174910cf0cd70c3c',
#   'f4cdf48b560dfb06d99482877ee5f150',
#   'd8a54471921322ff5131d604c6b263f8',
#   '93051e9eb99b81aaba14c5b17f36bfa9'],
#  '0ca1e61ffec9a1b2447da1a36dfcda16': ['a0fbc15cf4d631aaf11b34bccfb13ede',
#   '8675b88e0345dd085e943c4083f448ce',
#   '9347db688ba10f5fa580ab7bc259edd8'],
#  '0cff303a001e9144dbea56b5de62f2fc': ['12f0d926b2971e22984889f4b5b781f5'],
#  '0d093108cd6c949423d3ac5856951814': ['4441ed60c7d5bfab32d063f887c0c36a',
#   '560ec032a9b9979981de242a62120911',
#   '12257f0882e422e656ba7b553ee89f78',
#   'd315009657f9ad435c5ec372a90e49ef'],
#  '0d23101f5c0df04626b9c8edb8cd4f6b': ['8364a99ee4eb7cb0f9920bd4b4258067',
#   'db089be24601eb63c83576ddf73f5608',
#   '9727ffb611d0b6bef18506b2b404b32b',
#   '8d48c06b3a216bf1f5cbbd4c2c61cf55',
#   '37312ff7b32b9553caf180902234bf1b',
#   'a951daf314644afa84142e117408f563',
#   '5d553421c3e5567828b0a09017856436',
#   '166045176f8b4feb8fe64e01ae8ab093',
#   '6db5baeb5a07613566963e6d27bd35b3',
#   '095b42bea69a3f3449fb82c11b33eeab'],
#  '0d2788ce9296549b54bcd5d089008e96': ['c90e786b02a66c84762090cf30ab9e8f',
#   '8ea3accaf2e6f4883061f37138d39f90'],
#  '0d3bbb594f2f2dea63dd434c04666d29': ['0a1f64702b438e1869763b6da9548f74',
#   '7dd69b7a1d569f2b3f83c57011833ab9',
#   '32bcce60bcfd30d6d05fc0ff9a27544f',
#   'd1433cfb1b735fbb8a030e0a0feb58ab',
#   'd54dd4a970bdbed246dbb48317a1581c',
#   '69fc0a73d4168f48d3ff3a02397abc68'],
#  '0d817bdd2f4a64c5c29fa1220a5925e6': ['34b10364a8c1acbb37d261fbe1d0757f',
#   'eac0f68cf8d9045d7baff4171b12b313',
#   '8b567a5d0e7a10669caf54252fb4294f',
#   'c85a3c2992398c92d83357b47d24b314',
#   'dfde4e4e1f9c5d32b09f4fff09ffaf25',
#   'd4db07cd5a2d0a3877526851e408d1e5',
#   'a68b198a4a2e9739135aa5202ca95b02'],
#  '0d8720c98fd9acb9e195211fa7068dd5': ['e6e53d167a5f0d920c86f70a613823d8',
#   '86deb95951d92b24619a49de7de121bd',
#   '71410d30f460772d3b54d53ee0086e1f',
#   '0e2015fa494b55a37bcebc988e319241'],
#  '0da5178976487f9eb461e6b72c1632dd': ['45fd36b16198337353b3789963de746d',
#   '366a2d5072034849272a5e33a3d0f7e1',
#   'f2f7bbe976f7dfb8cf81b7af465c2c67',
#   'e8893b405c4e7ec220d67cb39034d8ff'],
#  '0dba019610f49a39e34ddf1e562204ab': ['227f0649982334c5a76e176ce17d9063'],
#  '0e235e0b361bda087c21b0634a7de999': ['88d5865906c0411ec87d84fed16bb29a'],
#  '0e40c040bbe6473be4cb964f31964b52': ['d4a79b6f4e9d17e86b9c88df2c6c820c',
#   '5a5fa9de054b16638a00b2b9002ab2d4',
#   '248ca8f9aa402eed77c80bbb636dc789',
#   '2d8b282d708926effc729ab01696b540',
#   'f418ce2eaff51d8757d68c9e65205e50',
#   '4f21d7c646ea90e0481c7acab860e1f2'],
#  '0eb44c64d5852c869f9752f25fe82361': ['37fd59f7e7a77fc6e411631fd1947bd5',
#   '793f6a662fcbe3f86450f89dbf14270e',
#   '3678f0afb0463018b846d7afffa372f5',
#   '7e1f63a65135d8026c54632b58b812c1',
#   'cddac0eb63426c3d43ca2b3e68d5cae7',
#   'c7966f15df3d395cd94ae5e4d846b724',
#   '65778833e7c9152ea7fb92129edea4d6'],
#  '0eb8dab77b0f789bc81e575a35a34fd3': ['1f142015a4a8bc07a1316bdacd153e3c',
#   '46bd7911f16acb2a8040bbc65a46c810',
#   '04b5ef50374bb02818e3e8eaeb6ec9fc',
#   '8525eac7a13357d9b6c5128faff4a03e',
#   '69d08a394ed592a6487116fdd0f7da7a'],
#  '0ec93391c08f70715906af44f0db1ea3': ['186a89756d4f65e173a521dee32eb5c0',
#   '5b2c99850ac94735cdef6c3e70da257d',
#   '266bd95a13441fce2f03b3d5b66dd80f',
#   'ba28d8db9246f1bfe32793f7a595b316',
#   'd06eb7f2b9f3052e55875227958b7861'],
#  '0ee6857a1356d30bc2c9bc215a8e4123': ['2be448f3adccea41c37cd0efbcc9bc4f',
#   'd9f0fa2c2aa3836d38bf72cd1ce21d43',
#   'cd0779e02b2e80cf2c5eb146957f922b'],
#  '0ef64fb0eaff1e6ba06c01c6c9c5806a': ['a78448f7a73704a7218101338c0f6104',
#   'efc974eb58daaf7eadd8211e5df86e94',
#   '08e56c71097270dd118530d470995dc0',
#   'a3de4ebf69be70fd03bdd66afc6839cb',
#   '90243cae108a28b9a9121f8e0b11b5f6'],
#  '0ef715212a3e20f9b27a5c00d3dd4159': ['5587285efd3d1ae06ea18059323136db',
#   '8a08a42dc4154ad5723bcd7d38f185ce',
#   'ad34dcbff58366f6f0b7bb171e7e06e5',
#   '38407def2b6f2097d79e9ecd5eb7fc79',
#   'ae1b3c1a4bf96b38274532562ef3eccf',
#   '979da3693fa5900adc66f3fa7c5e0c06'],
#  '0f00391f46ae2d9795ea6d5180f52472': ['2ef3af675509af6cd673f3643290f89c',
#   'c07f1035454aa92b1229abda677d69ac',
#   '239d9392bcd040c31be374e77d8068e8',
#   'fe1115277f921962ad21386cffd15467',
#   '8a0b6486ac6f3c5edad692ff06ccc8df'],
#  '0f2da468ecd42f800ad7ba0be8c48cb6': ['7e5f6aa92a86cba1ebed3e984fa363ef',
#   '48624c79762ffe0d4385aaec5e5f8258',
#   '7540c5b8e25d36903eef3caca48d8e21',
#   '3ef852bee437d2f822608f56a015f8fa',
#   '8264ed22a495ffbbbc4c94a54a84cc84',
#   'd0b2cd4bea7d2d05bed831e9fffe8ec8'],
#  '0f2f08619c7688c4c2af6ca0834de6d4': ['7cbf3f67466354b3614d9e4472355da7'],
#  '0f345f9a2e22136dcbb5d2679e14c109': ['072f685161fcb6c3ce07ef299d754067'],
#  '0f5d2cf8323257e0c309d4e90105349e': ['47bc4648a0431f4f3a1fd537b215fc7e',
#   '304c5cfe261b893aadee914983daacf1'],
#  '0f99bfafb9317467cb0fe721b8fbdf47': ['8ddb301fcf93a7ced7c0b25eb0d08914',
#   '429751f215eedbcb49f5e60be469630e',
#   '97839a034f10f5d72b047ff0ce1f098b',
#   '81d359486423fb1e6dbb060d1768c375',
#   '7e3a52eac1e96714b0709729e94fac23'],
#  '0f9e1565feedc676a23d2822f3411781': ['54364ebb8444b96965eb7a2aca41be4a',
#   '8c6b92c4135c7b7fd3309808d0e3874f',
#   '3e615b69a99dc62194e89f56ca97fba2'],
#  '0fd7de161a7aed16562a67b04379fc3e': ['b6307be3843068b53af4a901dd0a21d0',
#   '7e7f0ebce48ed4c66936a5977e161d3d',
#   '20f59b8bfaef0e0e05cd7d13b84f0c87',
#   '3610a7f092157d8d20e7e40fe14e0d93',
#   'f6073424891ea3eb0dc7ac3975d1c5c4',
#   'b994dd2a9d6ddc34a8a90ab2c19eec8b',
#   'fbc5dc013b3d32cbba7868c557259b9e'],
#  '0fe072ea2e22558eb895e596f76b3cf5': ['c65e82137656b930e1213341b0473846',
#   '171a6067df3b6fc19c9cf62b687960a9',
#   'd2127a43cb5aaa2cf65ba904f4b241c2',
#   '0642e9b9bfe7f1acabd1b72f53168216',
#   '00b6952fe748f8675f635ec0424e7586'],
#  '0fe81144c7b3042a110753b118a38c70': ['cd950983ce2db9120d1292e6bbd31112',
#   'fed9d28bb864c42ec072d309a87df135',
#   'f585272923625dd4adcfcbbf2fbc3eb8',
#   'd9c089ca1503e7bfdf2139f1d7b0e43d',
#   '045e6962d6d86032c3ab59a3e2d2d967',
#   'a9d4b4f7aa82e79753b89fa6cfc99529'],
#  '0fec63a24eb055c44daf023709015079': ['701d30f0e60fa42780cb21050212a41e',
#   '39e16fd1fcd3d8e35c01cc3f8c55b57d',
#   '75f59c97f3ee2ea7292dc08b289ddca1',
#   '9537d29b88d471b31ab7b6ac67938853',
#   '77a946ef4f9ab4d71885e3416d251bc9'],
#  '105876c0c2a07e9969bbb571f3b6e1f1': ['82b8b09880cbc64043e66358b27e380b',
#   '56583abd293e9c55af30f3dc2263a77e',
#   '77ccb3fbcf2e7e1c52e3d2345bb76505'],
#  '1094ace504535e204d096d16ce222708': ['e578df7d32ccbcbb7fb735aed4da3a4c',
#   '395c3ed3f3f9104c881cb6de1d73fa2d',
#   'f268f768bba046c6647024215e576aab',
#   'f85070f9582ecd9b4a00a4d6437c8817'],
#  '109c045cca3a9306ced113a607cb5db1': ['d324f42b66806522db3af664184a6823',
#   'e3b228a687ace9c89581b19d721788e6',
#   'c65d5806ff108dcbc8c85ae9b052b7f7',
#   '0c94ff4162784ee28baae97ea61b1621',
#   'adc1c17e213ecdd0f53447f741343e24',
#   'e048c84a0a253b469087ce360b0a3bac',
#   '4eb288542683e7b07a1846f115335e2d',
#   'a202a66a4fa7f6c5d61abfdc072d10b7'],
#  '10f79eec0972a7cf6948f12ede3f11cb': ['cdfb03c8814a19e76e6f283901a53d69',
#   '6b741d7eabf740131f63ff6396f07371',
#   '807348c63f86607cd8d8fcaded8ac8d7'],
#  '1145788252d5364b9dd0d76ab42ee560': ['9a182f78485ca304ecc87527e85a8290',
#   'f04d675bd73069bcaae3367e5858029d',
#   '8742631f2e6b74eb204326e331a003a9'],
#  '1160b7ff03cf7cfff2a9548679483fd7': ['f1ff1d0e36ea1b2a351105bf72c04ffb'],
#  '116ee53ed5cca11f195a2af52d09ca67': ['bfe45f68ffb4fabea38d7aac111947d6',
#   'c8e9fef8c350c4c79d6ea7ebe323a05c',
#   'fa97b8a8b40618b40301b72f6a039dad',
#   '227a43604fecc5d88469ef535ea1f39a',
#   '1ab0962d5bec83b7ba22f787496a0452',
#   '25c68b3977577936384d02ffc26cd9e6',
#   'adaf567fad385632a82d0d886cc852ef',
#   'd6e3f38c41b3640b233acbc3f144221e',
#   '9e68c6aa7a7c96ff7e72d76a2f224d30'],
#  '1185ea7cec10e4fa89fab41711c70ed2': ['cd3e68a0025edbc20831f6b09f1f45de',
#   '018463a2b2bc43b8661551ed2e283a61',
#   '278255175810ff492bc815f844835c5c',
#   '4b2098ee6e933ac9cf5edcbcbc4c6695',
#   '0d65676f05ca08b714fcee5b58360987'],
#  '11d67d0a26b32ed2b472f67e1e45fec6': ['478688e1b0002908f3087e18ad65e72d',
#   '06b8c0b5922f5820d4f02f13a0eceea8',
#   '89b83826e8c2671ede9875cab2f9b0a2',
#   '8a2b4d2df697fe08c47be73648f781e2',
#   '945d16c8fe6d0d25ebd8e32794517e07',
#   'f5a7392596e014b5f9d2a42e5fa44068',
#   '471eb1444d3bd8958893724e06cd74e7',
#   '22d5d8811edf0e540cf7861b86ce135e',
#   'fa09b7ce21f17c49cbb72e92815c5f1c',
#   '9fc9599d9d7b1c2350819cb28ed2b923',
#   '7b7fa013d29a81f33772997e0937a210'],
#  '1225a4be80761985982543f968ad2044': ['495793550348b4b1fb285d73b4e2f6dc'],
#  '123895a10a259f1c1c60bea802261a6e': ['789d18e30632c5e88f61706ee697c19a',
#   '574a4a0627b8f3b87b072778a76207d4',
#   'd20c21d979ef8714c30bee8287c4f974',
#   '658307361b0b133e2e966b5d54d854c5'],
#  '1288c39d1db2783c8164c46b297c14ed': ['ed9032a25eed3d967585132508f3cf2f',
#   '1787646efbdfc453e5705a5b626b15d7',
#   '67fa26bbd48704674de0aec09bd55311',
#   '21654d66188017315c60560227d70b68',
#   'd0fc73c50df6d07b18ad1805a0457fe5',
#   'a7a2233f519c152e83f88e9bef572bf7',
#   'b6b1414ce50dfd94941a90ed643353bd',
#   'f817ab5c839f5ed0e45fc2fa645e4d10',
#   '52a9c011a862c7a3a41440d1868aeb3b',
#   '52f988aaf71fe84221d46a3ae730b43e'],
#  '1294b2c64276f426cb051f51b19ff62d': ['4fb5be722f55ec80f040fdcf298a134b',
#   '111bd09d248419574a95fb381f8698b9',
#   'd92ca86769c520a24096918fe3ab3270',
#   'fbbda4e3262ed79219c9354ae9f6364a',
#   '38662340b7ecb9442092e409fa8d5c37',
#   'f1b7a54ca2f88a53a88bc9d443a9c6d5',
#   'd8571fa6e58bf1750317a220626ee1f7',
#   '429fd808a58348461597e4d270c4ca17',
#   'd9e4aa8f8fe9c0476351722cda13ae98',
#   'b1c1636ba655a8afec03bd2fe3c9dc95',
#   '6ac2b02933efc8daecbfb6104b929199'],
#  '12c4b9612672cf44b6094830bdfe028d': ['1f96f05e6ba7a1bb15596a8c343b99f6',
#   '661113ada4dcf464761983ffbf0bb085',
#   '2253404f316f1778811876449ad293bb',
#   '1791159eca21bd901904fe09840e4a0c',
#   '83cfa282376851a71f5249b736fbc0ed',
#   '1f4b53f1a1a7b3274c037b302c25d941',
#   '7252a630147a92a9309d5e4f2812e977'],
#  '12cebe6ad75feae4756377921828a063': ['9991dd47fe8cceba26865701657233fd',
#   '37b68d9bc2c3333906353e245037bbbc',
#   'd653fb970fc92655f53076acb2bc3a79',
#   '769cee05df99d30886c6a05b4f08513f',
#   '9b3fca497c5f81af6f04e6a896304eef',
#   'c359f3f1a3303ef5efcb40c496eddc2f'],
#  '133e37327f704b97d49a85097bd2f6f7': ['4f1769047e34bd094da8718b33b5ed89',
#   'ced5afa7e7da24ef2be15440e01aabcb',
#   '1500c4475b302117bb962647a4cf4c7e'],
#  '133f4923f1ab6e6e58d76735b828cd58': ['a45acb2f53f1943c5311878fb22fda1e',
#   'b0ee74d336db5b37cb8057c88ed69fcc',
#   '0b6313e40671fa93c2dc9ca141f5367c',
#   '1d4e0fe156da6c124d778d317af5bad6',
#   'c653afffe594b3dd66bdd9d03ae6fa99',
#   'de31117e8f1238d9ba351c0713079fa3',
#   'b27fd19bcdc44c6bbb961245ff8bfa3b'],
#  '1340c013b44501c7530a4bf37d0c6f51': ['5e9d0b6825d976240a81a68b3812b48c',
#   '2be9f051359ac0e563501ebd2f6c2b43',
#   'e5d668c6b0294cace40b487b4bae35e1',
#   '6591d52421964d506ad0fe9d4899f4b2',
#   '9e63076a46efb91c9d1486c03ab39269'],
#  '1345e4e56671d59ffad43955de5a908d': ['3e6ebc41a7ccc9eea8eaea30cbe22ff2',
#   'ff763245fc8f55da8249efc1209f6f39',
#   '9ee591cbba9e40092e013a9d7341650e',
#   'adad7ec56331bf233a2f9c28724dfe14'],
#  '13501445168ccfd5e212201bb641cbe8': ['ad5ba771a3692a0c77c28f63c3834ae9',
#   '48b937f2c695935865b781a9b90c8de5',
#   '20c0f48c9b0f6eb3f1254058ec0434f8',
#   'af3ee462a3d166436a9d0d3e00f154d0',
#   '6adca7c5a1d82b5a15cc06d9f588215e',
#   '3d979144cd73731369ad100fb37e49a2'],
#  '13512356ac24a713580c02a928f38437': ['72ce8393664284252b453f494df3cf5b',
#   'a1231e7e106b1ac7e543c3c2a209c8c0',
#   'dce0dd64565dcc897fe91b8d1a1b1465',
#   'd481f5f968c7c723733a0cdba79cee83',
#   'b7f493e3502e59c2fdc0daf3f926becf',
#   '5614080ac899b09c2cd327844d45f91e'],
#  '137d3f2a57e2ad7e0030ac7c09925df4': ['a09de21d2b90cac0ef0e5ced847407bb',
#   'b6e1b250c50ccd0102c24a17c8e5c5b3',
#   '400e9cd293a2b95451dce40d390aefe9',
#   '65477b8074c3989237bdfcf1ecc3a871'],
#  '1389623fdcc6c520d719f3326fb89e0c': ['a55913559d8d7402c5e850dbc205ba6f',
#   'd9e226dcdddcd6c42ad81231603a3c0c',
#   'f48c6de8c1d3d66352048275a6087d92',
#   '10a89c8d51201f1c241dfdd2d804d8c1',
#   '5047e538355d480b3d8799920624fe30'],
#  '13da67024c1dde82ae67fe5dd607f6b3': ['c24ac3ef93a0b7db42d520f483047ef1',
#   '51e73937d76d1d5711b84720029efc56',
#   '4c3393c193c3b22a1243f51490ab91c7',
#   'd2653f386f6525c52ffe30ab12febef7',
#   '1558ab1d14ee9161e1910aa3848d5c17'],
#  '13fb006d06210413614ae64450fdafd7': ['7687ec5d247e23d541c909836e375379',
#   'bd619c09aed272c1f6d0ece7fd3716ff',
#   '62dc0454ecb26e4839a5377c427ebe44',
#   'f5104f88a31e54f7f976539f34e9fa54',
#   '9cce6791e02ab007ce7c5ac975402be8'],
#  '14181856615c725062c04d696e8d696e': ['4a7202414d97df7177740a087fcb067e'],
#  '14438aba62ce0d4b8cd4a221783ed359': ['1f2e5cd0b4b4cbdab1ba4d95f977fb95',
#   '11eacd6e42ea83e4be2ebf7a6869b47f',
#   '5a9e358e12218e6be1303951dec27d2e',
#   '9f61e359890543065e810862e9dfd65e'],
#  '14498f7e1fdebcc0242d4b352af232c1': ['a3f2809ac134ed8d8ab71e1b82b88720',
#   '618fd1bb560addae51b4700990c64f11',
#   '308d917f33169a4f45ec7177b794eab0',
#   'c4e756520594574195cd0f584b6ed232'],
#  '14550ea214d2cdbdac6a47c297d10c33': ['bd4b7775c5c50244880cfb0b651c4323',
#   '84f03b1ca24b0093d7d0c66a75859f93',
#   '7a838dcb3bb77225b19104b7ce1615c6',
#   '3c87462597b6177fbe586a803ec96a15',
#   '1ed5abfe905a5a0b5da1db3f760ba89d'],
#  '146caa2825ffc0585d5394692726d94d': ['6a50f2ab93273a34b1db63761a7d7921',
#   '7461266ad5b6bb0d08629dcf9eb193f2',
#   '546aad601e6e8dc09588c081e2ad288e',
#   '677a19f6d9cb7667b81cd2c796c9a059'],
#  '14828e218ed1378f99338b1c7866ee34': ['a126ae3da830187eb1e949204a1f5067',
#   '819ed6ac1bef6307d9ef90d5674065ef',
#   'f59bd13d6e3bd1e32496817d0c35589f',
#   '8f2021ec6d1b068e4ea213db7b7df660'],
#  '148d7cbcab18ac224f4ed40fb9cb14df': ['827ef76ba51ea6c220245797989b49bd',
#   'ddbe113a040b83e7a1416247aa099c37',
#   'd3c92d5ad25fe56884ecd24d5ffbaed0'],
#  '14b56d138a3688d842f58ca3f085e402': ['38df5675543cb2d647c3b9da40b8f81c',
#   '2d13631ea7bcda80016a8b024d017af8'],
#  '14c34a53aa3d9327ac30184c651ee4df': ['de75182f37a37e29f98dfbf69ba59086',
#   '5ec4a2a6689550e67ad1bbe54f473edb',
#   '4173a49e099baa223b9eb62501eb9937'],
#  '14d0d372c7d2a1e3e19e31046f2f5c6f': ['18bea4524616a835f81c255b06fd6a80',
#   '49a27c1c944376050dac799e07f56da8',
#   '73ff068c6fa28c19634e80b7de2ca6b7',
#   '5a2f6b359a233dfc4a623e8c827919fe',
#   '6a240fb2e5a59e1ece4c5e1f86d13b92',
#   'ef83bdd4dbfed5a02268f411e36b5f67',
#   '3b6f5dcfcbec1faa29bef463e2e9b2fe',
#   '6e3dab616f4bbca49944f41829140f80',
#   '44d5065cda3d3837e6852d1b2f544243'],
#  '14ed975fd5c05962bf50dd8bdbbc731e': ['50b546730667ff62bfa3cd2ffdcb43cd',
#   'f8f81948aab26d07bfa1c7b0ec4552bc',
#   'bb3543447111b9a29f845653ce062b5f',
#   'a0ef0d6e50dbe2464772b0febefa9266',
#   'd41bff3f64257b7b17be3953aeea21b2',
#   'a072a9d6820a6d3cff5afec9c04b0540',
#   '7a78f312463a66d380c8a15bde667340'],
#  '14faea8f2cb1176e99eb6e08773ae3c3': ['1c760667b4405b397157b2df18a26938'],
#  '150ac895d26d24dfbf4c9ae9ca45f676': ['5dae43b6bce78d0436933606292b21c7',
#   '4bdbfee56f4ce5827c9aea5fc201710b',
#   '00611057c802304af36c40d9449db3ca',
#   '60b070e51100f7e5d755b69f6e975485',
#   'a58e4f6760af52ede8570eba1f946bb3',
#   '47bdf9ddb3d6450ff926104d9153cc91'],
#  '15252bec3ea55a33dcc5b16d5c67fcb5': ['7bb1bcd3a56a306957f64f861bd5f94d',
#   '7ef01d14fd93ab02aa8552ca6c07a23b',
#   'd094311914a544ada3055a2e99abd316'],
#  '152b3763c08bd99bc3a6dce70b00834c': ['a47823a6e209d1b596c15f0c396520f5',
#   '441b37624c3b5826979d26b8dc1077b4',
#   '259439f8246b30995fa8c60a8b6b64b8',
#   '497834955637320d51595ddfbd97a146',
#   '7cce97cdc37555e873ee76f5e675ccde',
#   '474db30f4a819d296c3849dda4815220',
#   '3a0342c0b813d3b7a383088265050fd7'],
#  '15550b51edf0bb09e0efb5439c104b4e': ['27a03bdd2df845815ad1079b595b27dc'],
#  '15c96f47d3b089ca50c0069774e97bc9': ['398a6496c73e470dc83831770cdcb0fd',
#   'b91d778c6692f507ad933a0f404b812e',
#   '27dd63557b35f856df7c7eb5370adab4',
#   '5d06219b23b1f9e9d568cdf13a6d395f',
#   '741aa5eede29153cc3341f2fc9917ea3',
#   '373042a3fbb35a832a418cf047e49ac6'],
#  '15ca9bb6903dab6df88414ede67dae7b': ['4ba93b8dd7fdb544dbf2f059aefd4d4f',
#   '682da53f4a4dc8d583165efeabd49c51',
#   '54d5d85a915ab4afe5050a46dcb2a74e',
#   'f22b4cdff02ab6807c39f284da73ab71',
#   'c3f26cd4f71be4819784c4b998678545',
#   'fa525a98d2f60fe0d069ced2020f4808'],
#  '15e192f938abdf9716cb83f8fa9cf458': ['b4d8718c025024233a381643408ef0a4',
#   '24e6df4b0432fc766453b8b5caeef11f',
#   '3e8e71ec471330ab1eff640c0c3fee6c',
#   '49c4c4c926184ed12291218cd8065604'],
#  '15ff592ea00a9aa5775271c646a028bc': ['64257abefae6156001a06849c9c037ae',
#   '9ca7185fab95801e6d9d84b892f3e5bf',
#   '50dab8206112f856d4bcb0f025fa53f6',
#   '8c8b9c071852d972efaf2512fac34d2f',
#   'dc33613b7a31fcbfd6f351cdfc901a13',
#   'a6fdeaa83832bc1d1036fc42f3f37426'],
#  '163fa1ad9b54354953dc01e442e33610': ['bed3c6a70a323d21981d48ddf86147be',
#   'cefb85e2b09b3feb0f486479b8edc7cb'],
#  '168180f2d26c9144b49eec4a31525bec': ['86e118cc3259a7c50e9245e9718f2da2',
#   '4936272a31587a23161d947d024e92b1',
#   '870fd0c66af82cb177530d4b5d3ab83f',
#   'b531418f3cceb5adb447af7eeca6fbab',
#   '80bcb7fc7b643ab2d6a4c32927b06579',
#   '60639b40937a59b5e3be939a3236ab8f',
#   'f5015422bbb761b3db1cf1b575f91e96',
#   '0770438e83615c5fc6a0cffafe18ee43',
#   '4d662af814bd8dfd4d27850c310835ae',
#   'dc31af76947f56a074b2217f74bd8c9a'],
#  '16a89cc9b658c4a3e6625fa09bc48bfd': ['d312df85d140ae568844248d9944d982',
#   'cb36c0ce1ae023e56394f5dedba68fe9'],
#  '16e07668e58633d213196874cbd64589': ['74fbc0c6aabc65735c5e4a5852317d22',
#   'e0f2b400e626dcb2f70a613a0155f962',
#   '5aed98311315e1ec19c5977236c484a8',
#   '347a1d0a02562111f37d9b6485db17cc',
#   '9943d3e166083608942824545533bbb8',
#   'd8ed3f0fb6fe73a7717bfaefcfd2c0f5'],
#  '170667efa5fa277585dd7ba8bb87fbd9': ['9a14715d2d501625fdda07ac90e54a2c',
#   'b5eb987a4c617e42787e656f47239921',
#   '085ee7cf9384a13a61747dd43b14570f',
#   '981b30a68b6b5019963bc7a8f6d80772',
#   '78a5f773a5be6a23a8f1727bf22f9273'],
#  '171d7049729c1ed3672c8fb16002d4be': ['a13ae730489a8255999c27b800b06407',
#   '5be1b0aa2f55fe8addc4b8b12183dd44',
#   '6ee4b0ba2df771be56f6ea1d016a418d',
#   'a2fbd9118d360789b43ab9aeee48e302'],
#  '1724b594fd602c7202c577cdb335a1e7': ['e23f8fef9d9ec5261a90b8fba61d2f36',
#   'a757f4bb548aeeea2fce60b996bfe759',
#   'ae304b32a750dfb59dbabaa489f7b90b'],
#  '17299d2c76a3aa2e27828e26415a7367': ['88432acaf45df78600b887c4e26fc43b',
#   '8af739c1877ba689096e4215accf18c6',
#   '51e7bc243c421d6c6eafec6918c24563',
#   'ea09c11d7fd80c9769e21c8bf54b65b6',
#   '3edbc5198e20f1f49bf8064f31344fb4',
#   '434d3beeca8acd1aaa5a52c9af777c26',
#   'da13f6e54243216dedf698f496f12426'],
#  '174297b8157536c9e3632b49e250855c': ['b35bda27428d7f61e45b75c41b078397'],
#  '17829df6cb6005396aff45681184a7b4': ['2b0ec7e49195d96906f85d2866eab76a',
#   '00063ad0557d1d459ed04071115a346a',
#   '00e855a3ce4f04c89df522c008fa8200',
#   '63dabb98bac16d302d2072f8c9ea8c0e',
#   '28ac43e3cd3390f8a5cf3dadfa45e894'],
#  '178acf9d3cfcfa6f4ffb383eb2abe2d6': ['94c480cfba8cc8b9fa7fd8e00a702b8d',
#   '3513bf8fe595c018be09f5fd048ca814',
#   '964a65493ecef5071eaaec0ea246f9e6'],
#  '180e48d9f230a98333ea35b6459c9453': ['db29fe73a49bfd17689e8351d229e4ce',
#   '8f8e1b9eb2a03439a3140638c4e45fbd',
#   'daadf7e4d97cafd578bf366bcca57c15',
#   'af37ad3bd6bf2f9f189e803ebbdbfecf'],
#  '18162db75a0360881b2c5901b7f7b8db': ['da0b32b1d7294a52b80d6eea1fcea16b',
#   'cfbc5c9ea84adf3075b03a8ff4e344dc',
#   '1f596cd694fee3b4da691ffb2d121003',
#   '0f5fb9f180bd4fa9c3828a787233d651',
#   'b5266d59e088564cf5d9061de0091204',
#   '7231c5f57140722840a582d5d5a9c1cb',
#   'f4b5ba8dcd77b9fc1375ed1965c1adc9',
#   'ad51f50e3d0e8f48ea3c8f3e21192991',
#   '1a77b5ec60c06f7df16c4857d29db9a1',
#   'bf353fd165509b75c214baeb2bef6701',
#   'bcd02bfc564b356a3e90364104e66736',
#   '450dffab2fdcac40a043d392e080838d',
#   'bd301c9f1fe5b1b41135b669ec0e3f06'],
#  '18209e0bd46348861e7bbd6e49df63cd': ['d43e256f79602f3e086becf44a72c975',
#   '62b1ab696d919404075a674425f96ae0'],
#  '182e456f20e8c0dae270b7546b7e6b4a': ['e690ca5c1f99466196c5ea4c2d68d953',
#   '9e9550c13a959c6787e798ef3054efbc',
#   'e6b3d8056ab29e9c3466c7a64318e116',
#   'e9e71a3e2c62d11c11867519470ac829',
#   '2527682348d9f5400c31f6dc20bcd608',
#   'e99fbb6ca341027dbfab283c7cebc0bc'],
#  '1843542cded7f50a715acfbc77eaa275': ['7b653a47ebf623d4a362283c09b7112b',
#   '58764aaa360e740538b78c2206a12811',
#   'c6be1333af61cac63c19f6c177d7d033',
#   '46a2eb8791243b30d5df3e92b6a8559f',
#   '53b316607f4e68b3ff13c41f20e2f4ca',
#   'ecd159889987f6a727794ceb81078a50'],
#  '1855178ab9792d5f85996724665ecfb9': ['9769fd3da9cefb479920c80fab258974',
#   'a4594b5cf0bca3236573f53d55798360',
#   '68fc8744b460ffc457ae38c08884512d',
#   'f2ecfd7d9811dfeb22da8ce9f9c8cf3b',
#   'c13e98b49fffe2437c7a29be86b0cbb6',
#   '51d7f813da5d561d5d6a6a8947ea8395'],
#  '188e39cb788ee0829d0335c0d411c414': ['258019b9fcd638591c300748f906c903',
#   'b78f3d09c193ddce95000dc18aafe7ce'],
#  '1897a67f1b8585907b7a8fcbcb90699d': ['cbdf7030a8939a711b47b17321f3109a',
#   'db6ddee7b94a5c71efa94090c013e991',
#   'cfe56f26f0f33a78a94e9374ebc806ee',
#   'f46f73fedb0cb08597a1af8372d894e9',
#   '1efd1862e9280e481a4661886b6810f5'],
#  '18bcc619496990aca7afba71b3ceafcc': ['4ba84b1dcdc149eb284c9cfb4935c203',
#   '8ac632c1ca3a73dbdafc12aac11ea89e',
#   '1096e84ebb7b837e9000c53427bd1009',
#   '51c99d9b48a9ddb9e4b051053f3c0301',
#   'f51cbf06038e13f31bc959120dfd5ea8'],
#  '18d112fc0688df3cad27baf99d2a6f64': ['47676f8bc35de0b5b2bf0837322b5916',
#   '7fba5110e56068077acd25f4ca20740b'],
#  '1907f1ceca0dbe3737f6e0a584f1e9ba': ['e49f0619138f5732c0497e249dbdd138',
#   '3dfc8615940d3c2b957971dd7f4369c8',
#   '91c35a20fb699634ffe144c1b39a617f',
#   'beabe46853f967f6cc0b7db8a035dec3',
#   '3974b294a124d1d14f34b77197dd5081',
#   'dcb63bd7791d40ee5c797924decc7cd6',
#   '2976e94faeec6c124ccb5c3b1b7ad117',
#   'f7180b67bf01432fa3b47f41244423fc',
#   '669012fe9221bdc27ed247483571165d',
#   '021e818d13801acca73962ed31095d65',
#   'd4be5f3800da0b10ee1e13f8441c1ced',
#   'c9067466441b057fbc73dbba92c4f2dc',
#   'b9fa1374bb8e06b37e78490931ace9f0',
#   '4298ce802410a95c39cd6f9c850befaa',
#   '12a3f737ff75b1232d2f2bbc2dee2ac0'],
#  '191c28eea8ea52a2ac7bda9c8ecae641': ['5049675d1c9cff34ebd03f52763accc2',
#   '9d423fc19079970d7e36962949055d48'],
#  '1930ad81c7fd2a5657b928c0667fffa2': ['5f99222e4227f8746c9fd5e5d007ea9b',
#   'da72136f76066589585aa03a0c2de816',
#   '380cf16e122b51e66b813144aa2f5a29',
#   '8451727cdc1fac32b1fa5b425f54fc16',
#   '05c4ee9cf49b96b246a58b304caacdfb',
#   'd58a693b8abbc53b77b21c09523eff9c'],
#  '19372b288f5fbe26bc1c5668cb3fc1ae': ['a0f2832d6ca605dd931fd5b475cfbd3f'],
#  '196f522a73230878726d3260278b5fd5': ['c23733a594afcfec32abfe74fc430ed0',
#   '75d52ff919792fd80ff3e775452d96e8',
#   '8fe8df5615fec4c577f7c2f304b42e1e',
#   '64a7b4e26d90c2e4f25efcb76abd1779',
#   '360c5b166180b9d3c44cdeaf208b70cd'],
#  '198aedd4ffffcfdbdd89c79df276d71b': ['a321aa1bef00b094c3b5ec45f50a235c',
#   '03c3054de316d908d2b9794a002ed7f3',
#   '066928db25fa642e454b49fcd09b5c3f',
#   '20d234c98225b8f561e652591bf6504c'],
#  '19a743bb63bd38811f615194cd362734': ['efb6994e159ab7d16f2b56296a0139e2',
#   'd694c4cf9d4de06f04cdb2d9758e0ac1',
#   '6093465e2c834fe0b3b39dac7ce82414',
#   '4e8593beb8f5dbcf2e90f27dd1f6834c',
#   '77c1bbca72848a4e1e4f09d568bf031d'],
#  '19aebb453b950757362d6a7d7732957a': ['adbb08d90e108b73af799cc67ef83335',
#   'd2b66e537916721ebb73ea1284903cdc',
#   '70a2027634a6c68e571a7ff6b096d05b'],
#  '19cdb41a6a055763854d8eb8fad038b8': ['4c91c16b1c5210ad472eb7224fe5748e',
#   'd15d91a820d0330dd1a860cf7aef65be',
#   '170511ff582c666008ac1aae36baf189',
#   'd83e5f02ed14a1e6e0eb9e3361251d3c',
#   'e2309a079f829ff23f11323f851a107b',
#   'eaae4799d02eb5879044c9c57e13c1ff'],
#  '19e484152df4c3f602952a2634d602f0': ['6246e54cf54dccc0214b57476c86ac70',
#   'd2f5fa3df900eab40cb85a014db4558d',
#   'f8e544b94fbf5926b8f77eb671997ead',
#   '9b633d059aeac9f922986ee9c019101b'],
#  '19ed5bdbcbb951b085c40d4b97e85e2c': ['90ff1f2c43604819cf8ced835927f648',
#   'c0d0240db16cdc3158e0d20039955924',
#   'b44a1684d9b475b91b445ddc4cb31621',
#   'a4d4d53f110d99384d606202ea8d4361',
#   '4f3263416d02d6c1b187b9a5f9abe60c',
#   'e57cdd775ea3e0eb79c8fed205e0c3fe'],
#  '19f0c772ad5a37ec92f314006180f0dd': ['71df58aca604cf88b030928d53f9cf9f',
#   '5b2314cb564405d6df3f6ec076566593',
#   '50360d4d93c72737ba9cb72c19d3e094'],
#  '1a2f3f5944d15e0025ff394a77166760': ['fb2b4e762b005f74083423e4550d154c',
#   '6334e76a5b8b9f32f79ddc1a251243cc',
#   'f7088102d66f14563edea57d53aba6b0',
#   '9553ccb9506d6ec6d90c1d9ff0df8fe9',
#   '74d181f5d6024312e366cc8e855dbde3',
#   '5eec505ae8e07f50b9c5b30be544c060'],
#  '1a60728fd5883d3dca1b8c84b8b9418d': ['f453b46de42ba9043304f42b39937903'],
#  '1a6d431bcaea6f3db9099b52fd7dc61b': ['18526c691599d8ca73ef208903576335',
#   'af8542477adab05b47d0f8914e703f9e',
#   'd707dfeeaaccb23c97d66306689ae83f'],
#  '1a846a4d701b0d938d7c11f47f577ac7': ['b828e29621ad340b0eef1a83c3d4c35e',
#   '739bdd93b93f057757c11ffef571a73d'],
#  '1a8e07bf30567932a26c7f21dc80b4f8': ['c43576490a41b10d231f1a9cc09b6e9c',
#   '421cec9521084498b504a8225dbdb47d',
#   'b711bfd86a755242466d2876f0bd36ed',
#   '3bc80fffc44d582d18b35b1193cf1c04',
#   'f941783c494141e0b1eb3fca8b7ed8fe'],
#  '1ab78998a42403271c7665db72d53d3f': ['baf7c8c80759ff385c281e3e867c5eda',
#   '3fb3830194854f0add1f5190daea2537'],
#  '1ac384dc3aae93c45e6fafa16bc0fda4': ['d8ebd58bfafc4010f2d6de949c75e5be',
#   'd80e4bc371f27739bea6b36e341ccce5',
#   '47c492a830b3b49f48e33c630e6db6ae',
#   '43f3eaa02ce2510f7abcd625b8d63f13',
#   '101bce07d01a4117e0a7dfc4048fb6b4',
#   'a8d29ec7e1a1e4c8f4c1e43bc973987f',
#   '3f649b4f903ae28e5da3f63cf1890620',
#   '13cb1280c9f636134829caecb21828a3',
#   'a2487f6fe91e28fc25c999d139458a34'],
#  '1acd9f84ace636c5d133c82ff47d5282': ['c99ae13ca55d76e15dce6e07c60fd7c8',
#   '6f2400512098eab00ee15a94d692fef5',
#   'b4cfc459996f7e80c09bc94622a9cf43'],
#  '1ae21811e2cd0808f944f59374da3a1f': ['e438c9123b4646cae25f35a51a930b9a'],
#  '1af78e4471fe7d923b8b861a969866fc': ['bbf810e0d4a27cb3331c876faaf38d2d',
#   'b650d99db98c57071e330365700a797e',
#   '3fcd3d8168ee459fccb8051d1a8d036a',
#   '83d59b1d01b63463b128c29c866d171e',
#   '675ee9c1eb15969f464a956a4ca7de98'],
#  '1b051a35d23f8e479fa0e20de7d45250': ['e475a4e0c5321c7e9014d4394d29a7db',
#   '84f373cacc36dd799479f392f3a349b5',
#   '0e9a72bb2355f80517a98a41b7f48da4',
#   'ce260c21cd11d9f5e15fd5040622ca0c',
#   'cde50e0fcfada16d329ec3d5b9401ee9',
#   'f8b76129b7d247ed4d8a25cf42447c84',
#   '2c6bb59cbdcc1cc0afe094974c9b5264',
#   '9b11d9178c4c2ac7145d1d53df71d5f5',
#   '891bdeed9c2bfd912c7091216193b721',
#   '970384e9734501c20a56bbd96a601b08',
#   '328845211a337de72129691e50ea6581',
#   '2734c963c10516ddc92e6deeb1556c08',
#   'd45d15795af9a3f52bbdcdde35875c30',
#   '0d2db5fc772aede8b82d304d5428ed92',
#   '34f818b896509a6758318a404dd3979e',
#   'bbba381d1c4d08b3af0cf7e1b42dfda2',
#   '46f131157e93448dbe3b2bb9559f0d9a',
#   'd0839e50517033cb0cab263b01b9ce65',
#   '4cc42274516dc39c9c20bfe11e6d8e7c',
#   'a4cc94d4a4b4ddce9823e3c58fb0ff39',
#   '729504b2ac35e52dc97156a361f07443',
#   'c0ea23b8cd028c7a3c0934d60d195102',
#   '3909b5ed81759ed4050747a402a45f5d',
#   'c736b89bce9a76cac53dadb70f0d6cbd',
#   '03bed5d27fd38b65cd7ac2cc537bee67',
#   '5d69f5500cad7ffcc1e59bcc6b7393f2',
#   '3369d0795d8d8c625681becb6cd53734',
#   '1dc8664920ae687bc3277111e7d8c3e6',
#   'b94e775f597d9ff4a15a2352a6c42a47'],
#  '1b066cfd30f0dbe7f23331beb6b6353b': ['f7de8657876ad03ce001944822953010'],
#  '1ba983fe65e90156bfd7954f032e5867': ['2add12b12dfceeb5c3dca697be447d03',
#   '2780a8673ef9cf7ba6f0ac78d4e56864'],
#  '1bb2df4b128c6268a9737d64a2541faa': ['7a5c9cb57a2b2a406297b2e772159a76',
#   '78618d5cfd812727567259d5e762e3a8',
#   'ed85002b839ec5693de5fdd1efa860b0'],
#  '1c216a126874d0d97e5b92317c835cd2': ['611ae3d5ba19df0ca6570e56f6fdc2e0',
#   '2d3295f1cbf0d019b644c81c53cfb02b',
#   '95a9f07e88554ccedf0ed7008baa42ed'],
#  '1c4adb9be7bceba86de6e7d0f0b357fb': ['5415c3e6f5f3b793f5f7a34234613dfb',
#   '1a58f5fca5449f516ce49cb558412e92',
#   '32a792722c4d7504f718df9fec5ae413'],
# ...
#   '4b94a73dec1a212dd1056baf0be5fe68',
#   '276ee0b8e4f93c3b2c180e8fb10a4983',
#   'bccdede08029d8667c5137ce228d6756',
#   'bfd556f5e57e2b8153f0e7cb8dc66821'],
#  '7b47861f4e0dcb8ce381f33d9d24d257': ['9a5020447234dd7a0857d94e7b339d6c'],
#  '7b4be579eaf6182ab02f50884a96bd14': ['5524b1f56a19594521de631483842e54',
#   '0e35f04e38179a87c83db62f64b397f3',
#   'c5d963d5f3e6a8b6378e91c94f077ff7',
#   'b3fb3a84010f72c1f26f10f7e05a288c',
#   'b2efd1242d90f1f46272ed1e28520ac3',
#   '982cd81bac2db97b812f7f3ea15ee646',
#   '5715b187d0d0bab70bc8c671d26cd11f',
#   'ee0bcca5c6d59bef531c07a0a2a3678b'],
#  '7b6bda2321c7c6570ff6bae264f514ba': ['653d6bc6863630c6259a12ed5aee5957',
#   '0b744d1dcabc410b4089000079437f32',
#   'ecf90e203b4d16b67e1bcc60e8ae0d1e',
#   '600e21469d5ae68e68a8f7bde0f8bcb2',
#   '7401db4deb0b01bff1aa90a2e7e60b9a',
#   '2f9e86c26a325da1c17e943fe58e6526'],
#  '7b7d1489d002a693cbec308954810645': ['1a438d671301c12345f9607e366fe101',
#   'bf36f4010c6830c50d0acad3663537f1',
#   '58f834fc3ae66fc8c3fcdddc78add5f7',
#   '961ad2dcfc14baf704bafcdacb98ca2a'],
#  '7c0a87d2d4becde8eda89c601a74fe97': ['7c4618c4d3b2e6cac9a0db07d612145b',
#   '3e0a5dba2414cdc7582f93efd49e135b',
#   '1d9325112d321ca0cc36c7cbda96a5be'],
#  '7c3545505a01cf39b634a071fc025163': ['832f0b88ce95ad87b46f38d8f75b74af',
#   '1128fb3b83128ed40752bd0b9cd6f7d8',
#   '31047a3a539040834f7e045ec96b998d',
#   '6a52983eed7c0b4791d74dab301b96ee',
#   '9f447a5ada17e0d6ce8db7c6a5da2650',
#   'e1ffde2cc79095decbadc84f372dbfa4'],
#  '7c7db0875b9e0b314f57bd293b0dcd89': ['eae0ce10230275f52663105f03fd40c8',
#   'dfc268bcfd517fa5d4db53f29039304c',
#   '12512b4b46218e5b4690fbeb17548ae7'],
#  '7c9babc52ffb6133582ab857235bfb89': ['9e7583828feb5b117afa528ec1e3583f',
#   'e5da301fd4260580a62d19985bd0c6ff',
#   '365bd2931c07837490cdb5ffcedbf5d7',
#   '5c5f1050624049815934859af5777514'],
#  '7d0a36c71f7666df0783dcb10eae025c': ['91154d47a6522e9c6c6230295d710a2a',
#   '85c6f33f12d8e2a9705f56aa37b373bb',
#   'b032f5e289f5c8af2894ddec58544325',
#   'a95bc0630231ce1adfd6b7a573619f8e',
#   'f42a9ccb5bbdb919a65675c8fe419f08'],
#  '7d68a7b7620a1d76df68399da1cf2da3': ['3b89d472e0d21473d559c5f296ecf9d4',
#   '06a769fb5b763b99435e382a74fffd7e',
#   'c1c4596aa0ca196304b4f23242a15311'],
#  '7dd8d2d6bac72ed3d633fbc21686d97b': ['cc962d3b1211507c90aff97c8d27d8ea',
#   '8823903a4d6009fee74da7e3e6f7e8a4',
#   'cd37c8b6dd5b0272d00a7fd688d19fa7',
#   '7feb199bfc94b3cca4906d738e5cc0fc',
#   '9b704f0b12166d29c162461e839b358c',
#   '791bf516a569473e36597002a945ff60'],
#  '7ded40e31689837342f684657175f895': ['e8f444d2c2bfefa76f4abe2d8131614d',
#   'b6123961ac743758a9225d7ce3bbe3fc',
#   '11dd5379f950db75651503d51ce65ae2',
#   '1d19471c77a50c1c41cd94c0ede6a8a1',
#   '74b5dfec1d36b3c851c4475c74bbd910'],
#  '7df068f740fb04433f133b0b49559932': ['04d0cc73eafadb47fa8cb94f8af489d3',
#   '5536406417e49d9616a4a63ade737a2c',
#   '9cd8bd272ce63221faafed483827055e',
#   '559e195269e9a3f5f8f50b0245cda908',
#   '43a27349eeb6b7a60fa6b80ba5554ac5'],
#  '7e22ace8c9d3fd0783002fff9a5f9d90': ['d29608ea670d2563c1c089b276a870b8',
#   'a402ca8fd0cdf371bb010f22f89e4a6e'],
#  '7e2b8cf1fdd18bd47a0ea5ec5de67f51': ['a02e1cf8eab8084d45f1bcc612df91da',
#   'b18e755bbf953313528e54812e516d81'],
#  '7e32753fb3ee8a1bec4d360165b7aa30': ['f1d332c069180fe037f9e37738e82b77',
#   '0e1fdbbef7985303e70b9d84b2cd26a5',
#   '6373f91f4d58846c9939b8895d05bff1',
#   '00a2cf6fc1ba276a8d4884b7891b2642',
#   '9e8cbab3d0decf52dfbb99c6d31118cf',
#   '8fca20cd2b6ac0f2324b957453739807',
#   '9dd6b06ae4e1261090c291b9cc3bb00e'],
#  '7e3607486de31108a1f8ebbe3b6290a4': ['40303cfb6b7b7dc3dd0719a533162264',
#   '7d133b18bf9d40bf2412219823b74d07',
#   'ee570517d6ac2275ee880d8dc09d62d4'],
#  '7e53a4131b003638763c7630a9c000bf': ['0ddfe5c33eea3412f18989ec834740df',
#   '1ea43b9b756c52a712006a50ff7c66b2',
#   '0ad12654846b60fc16aaf390f043106d',
#   '63b5dc37ff9caa964c202383a0f11338',
#   '167d412415c19a25e58d545c653473b1',
#   'b2eca5343a8dbfd591155db572f036ed'],
#  '7e7fe3dc5e4d9e3056020da3eb1e7fc9': ['854c51f85fe1db867968e10e9166a94d',
#   'df3f7ba6679101a86ff9cdf970bbb74a'],
#  '7eb3b62f06f5d135fc933855b4eb82db': ['734f3f8e6f37d80763f2e2df81ed1239',
#   '982d604652ec258e7cbe94d6c235bfc3',
#   'a620d78df4424e7a074ecf461db27788',
#   'abe10d2e6ee205ae34966c841080f673',
#   'fd62b113f9124409fbc06a15a2c247b9',
#   'd6d288d43745b51639332b0fb218f3ec'],
#  '7ec7fccf03b7b0c1016cc419bac7f98c': ['adf11189087eb2fba1914b59324e479e',
#   'afc1ebbe8c9674b797036d8334745d65',
#   'a94b671bfea3a0605f3148be6e100806',
#   '9500aaf1d23b2ff3c1cc157b82ead3d3',
#   'd57957f1dbcf071220b26b157eeb68ca'],
#  '7ecc472b8ebf96ed02eb0282f701b907': ['211cf622fd314b7851d77dbfac92c422',
#   '6d204850f98e68d5164b86c6625b8969',
#   '1c62e409ad60c410f7b012ae23901ba5',
#   'd1c9c1da0f0085b667204521d4997745',
#   'c39bbbd793cc7aecc6bb602593af89b8'],
#  '7ecd76d4feec3dbc671c00fb6fbbf0c0': ['2be3603d3a62964458a4ed53846d8ecc',
#   '34378915bbe51f9166759f5e047adbff',
#   'f3eb14477e561670311a7e7dedf6a277',
#   '588fc78400a64c1c3070c0263334bf4c',
#   '2a3be15b5ef882ea10c1482685a4e3c3'],
#  '7edd3649005db7792c980d4dd63be797': ['1f32ed1a86afd085e748e9d82f60d337',
#   '2485d5d82077cf157068e006cc789900',
#   'e5cb3bec50eff67feaceab36627c2ae3',
#   '515fede2f51db4d866be572b33d694ff',
#   '21d98ea4c1248c8cd82e3313be92eed8',
#   'a179b369d05dd6967c8be5a4a34c2c10'],
#  '7ee9228dff92e19657f2a5d608020f77': ['d7f13dee4bb171aef75a506166eb709a'],
#  '7efe4eb4000f1d5718f99fb70c531945': ['26718a4d6fe573c39e42a7b09d6d6d3b',
#   'e283e52f8f5612c2e9caa8926b01b100',
#   '5a445c1fdd5f0112736d0243f5fc0aa7',
#   '3c72a513c939ea5bfce4d1de25843134'],
#  '7f38443ab6d58cc50f165be394fcff90': ['6e636fa84b4e41123bc5663b7fbd0480',
#   'f1fe8a27a5699879c92282a7fc4b5f9b',
#   'c25ea2cf76cb3cbaf850fdecd84bb988',
#   'b85b4d2eaf499a24ae61018c585d7b1c',
#   'ff04d142921edee939d63d758979f75c',
#   'c81852f8756b3d4ff25955b00a3b29d0',
#   '135bfdc4a0f5aed4e4ab3eb22e48fafe'],
#  '7f7ff6dc3308320a4fab97f49f1449ae': ['2bdf9553be9908fb80fa389d464736a0',
#   '215f65b433ac10e875a3d186f0d214cd',
#   'dd5377630739918287757c8a8bcacb57',
#   'c41b049add1e621db36079fed74d9f43',
#   'ed4ecd5f2daf7ba591b8e048a6307ef4',
#   'a65361de0ef27dba5079f883bd65b00e'],
#  '7f819306c5e7ceedc02040e923f0f2d6': ['3788b0436383663784ad922c8ba06fd2',
#   'c129b4a7e0b1b4fd4074ffc7da2a0a53',
#   'b02b13e68764e7d37077e41ceeaea52f',
#   '92df0f0d0b6e7cd2d3c822fb4a3c19a6',
#   '9800752d8c6a62fa28017b7cbf7070d0',
#   '3ee66d174866c0cd5cedd776b03ef2c9',
#   '995bbdc644f258a8c45e2e4831c65d15'],
#  '7fa66bc9e1d49f0fc06d98b2f307247c': ['f7acd5078bc916aaf6af6e0dc4fc244e'],
#  '7fefa289fa4534bb1f819d1be91c97ca': ['4932071fcf6ca5d135052549ce133bee',
#   'c60e3bb890d8673bfe3ef28ffb4501ac',
#   '1fbc48991e566ff59f77f42afc921003',
#   '002fc8bb7342a5955c75e8224d1d0363',
#   '6b97bf25646f94ff7a7091e0b7187dee'],
#  '7ffdaccd1ad0d844e276e21b4385a639': ['3784bec9d9eae10fa6d32fdcbba781b6',
#   'a303fa67642ac89298c5ac812a6abec0',
#   '4c5a3870946699dfe2830289625a2c77',
#   '72303ac195091f737c1d7113c8c8aa10'],
#  '7ffe7121e02777acfc9854940574aed2': ['a7489b0f5fbadd967702c7ab491d2d80',
#   '831c80f722fb3b14d33870a5fe5127d0',
#   'cb3fae5a2dcd0b9fc73edf766a32785e',
#   'b7bdb1cd7b40b32f1bba7178a788acf1'],
#  '80086bd44070dd02666b3f66bca2320f': ['edddea4e8e3d5ed92674ab8daa0e0f64',
#   '77102faab3740948d0f89168d96d52e6'],
#  '802eb29219626a800e5c05c5b33b76ed': ['92abde6ca8e7395d756801adeb2f286e',
#   '9f7564ca21391f390350f5fdc08ed3f9',
#   '96a9a414dfe6ad6346ee44d50fc12db2'],
#  '808fe738c5670aaadd5294824c82c7ea': ['013370bdfe321cd6517381c6e7a84af1',
#   '6c354ad3b73f9e2deac451209ea9433a',
#   '8a25116eb93734f4e0225ae9f1637c8d',
#   '463562c54daedebb3b419ffe118b330a',
#   '99ca12ab32f4e8fd61e4748d06227261',
#   '89dd994f3158a22386fbd3035ea042ff'],
#  '80926773506dc722b83a4a482efeb69c': ['7c8c69eb998457d9077e4029ca9f97ab',
#   'e25b1d3383664913aeeb4a5691de201e',
#   '14ae485d67ff2ea1d0181891bb28613a',
#   '06391d6b8cf29a0f821050217a8c0c26',
#   '053397d231680b7adc2d563c962a3acf',
#   '4e5df6aed7c377745ae3855aa151ad37',
#   'a830f978f8dbe24f5614b02e668dd4b2',
#   '9b1e88af986929a1b11ef1ed13be9966',
#   '8d08128be9c7d2d81d652c195db5bc9b',
#   'b13c69dbeedccad2078a5b8540ddeded',
#   'df837af7148be54760e68632bb11ba35',
#   'e97f06bf4bdf05117f5e9485f7be82e7',
#   '7fa70a519a65d0a02240b0694fe21826',
#   '97f553eb0a55d41eccd0c3c1dcc52ce2',
#   '5e332dc3cb7e96d4107efce26d576e8f',
#   'a964fb072fa3c740e90d5f1c36ddd07b',
#   'eb2e39d99130a7f74f355c6e78e9669d',
#   '4af7c7d66e6ff739aa7c432d51dca517',
#   '02e1698d8be2df0303e501ff167da599',
#   '7b762543aa4edb46696f42029439e55d',
#   '6fde840a402983e64fa2c92a42e2bed2',
#   '5901c89bf2eb1fe5653e9b51e2f575e3',
#   'ed20e9e2996d7b8ddba95b89bce53c95',
#   'e66c11cbd183b1fb3bf71bb8e04a9700',
#   'bc03ce35f20ce2d56f4a48d61c06e364',
#   '34c15aac1d848a9b73fc5ceef6200f60',
#   '98642a5e290170e51b33e6fc41109f35'],
#  '809d888348ddc2130088161003cbb451': ['ad9a8f4714d90a1d1c6651a0b7e0bb1a'],
#  '80a18851edce9212ae83777fa58fd146': ['d9274b6ee6e70fa8ef2b7cda58d1a177',
#   'd0d7f04584f725e827772a8671757f0a',
#   'ed4d742b1dc4571ed7984e1d85508c6b',
#   'e45bf23ae5b5d229193a6128b81b5532'],
#  '80a397c2bb6e392f717b4a800e248f5f': ['259f62fb5d86dbee0ca8c1407a5f8e16',
#   '0b8bb26cb18772c6d976153f317b85de',
#   '5c8ba75386ba1528e377fed576029514',
#   'da2cf49a391ab0acb2c95aff913da582',
#   'd20288dea9f51b2b82de114b5be52c38'],
#  '80bd5d878b5f1492b76a0f24340d90bc': ['c6189564b01b11ec9d0c02815f18a97b',
#   '43de91ad56309ad1cb1a80a0c96fa262',
#   '6dc0e5a71b4fbe82b42eab0ed8158b34',
#   'c82b5afdadea6becd603868dea79cc75'],
#  '80c7f8aa1bddf1dacd1fc3e4028feabd': ['960547887b25f466cd2deba302797ae0',
#   '3634fdaf288f4d6453908c0ed1021dc9'],
#  '80e09cec88eb3c92707d6714e99aa5b4': ['c47e6170f4c56d275d656a41d1f95456'],
#  '80e216e0646a1eeec819a79298e8c49c': ['297a2d2e0f8b9cb4eaa71ce21b609995',
#   '4088dd48aa867da09150f597883ff983',
#   'f53694f7405e78da3ece2a3293554373'],
#  '80e6f1843657ad0c6178c9932daac50b': ['3968b8adcba2d2c8126d606d7dd2578a',
#   'f965d84bf92d7ad28e8b38543a21411c',
#   '8feb5435542892515dc48a0f2949b91f'],
#  '8165817305ce9df2aecabcb0ac4c5b38': ['9221250d7ce9c07c162b277f994b8139',
#   '7e144b4a355339fa4ec0dd9b1f41d11a',
#   '847843caba9928be0ac39f1d0d5da3e5',
#   'ce6a5a0384cfd037cf19d682060764c9'],
#  '818a79f6d72295a42ec0b7c9eb93c082': ['603a00dd718e79cee226e20ed8992a72',
#   '5e3086f1425ef227a1648e27fd3a693e',
#   '74bc6f6a2492610c42867a6065556f7f'],
#  '81d9c95dbd729e127e264d3ded78d849': ['488eb2ee333b3a27a407798bf8bb8127',
#   '2fa96aa030a5a23a3dc0cfc295b43221',
#   '889acc52ac87bda93c011b0a8d186cbc',
#   '0ab1e8528f064372811c46b437ebe0bf',
#   'c1d2763367b6bb0599c33ef529efd88d'],
#  '81e38d0e106a6f74334f79b4f799d367': ['8616acded8ac9bcb1374a8e533d75b77',
#   '2a76ffd187f73120ff0aee93242bd90f',
#   '0217d459e15acb73854b9d419bb51eea',
#   '2ce97f9da107377e1c3db37f2f1ede44',
#   '0aef8a514765a41d1dab4cd14e274101',
#   '3cc56a977c7cb558541854384e3c1c59',
#   '6c208836c74e4786263cb15eee3c3a33',
#   '69c0d8bf1f523df12543f3133f4b65ce',
#   '497c01d51a61128b926af71bff484906'],
#  '821f05cf9a121c60f130ad363874d4f0': ['a684f7dcc3865e80accba340dbb31b92',
#   '792d4ff686d4a2e922d5e82358ed9d42',
#   '9dcd05bb16dc0a443ba4e2a0f4ed35d3',
#   '816be63c5d019c10d9642a2443544473',
#   '8a17337246b19c6e4743c0da2d291d71',
#   '1be69c82dc12ede4f53344d2b94c6d23',
#   'f69d209761c30f63909f91b11f974ac3',
#   'fbdd049a45e64d3901d62f2717bb87f2'],
#  '8222fad1ba4797519b86adad9903c4a4': ['45d260b7b4f2969a74ea51058f50a676'],
#  '825a908221278a020e776fc47163cfd5': ['74dcab8f7e073f54e50fa98072f3beb4',
#   '2000b2ae10315819ec1d70bb9c2d432b',
#   'aa2a721aee65a3b785ce6c7e9ca2c641'],
#  '825eca166d12e92a32f796d9b15c9cf8': ['833d0008fc6ef341a4b37f59c5695673',
#   '21092965a86302f750e59ab52247cd0b',
#   '5eb2f20ca831c58ecda3533a1afc6c40',
#   '57dc10952c73ba7fc4a670070e5fe462',
#   'b1d282fa842b66782e4598118c4bfd95',
#   'f0620eb2175cfbfe017b38a7996a87cb'],
#  '8268833bb92cd94c8811c4cadaac0d0e': ['331132a4899144e645e570a1b2a54cb0',
#   '2f39e533635d52aa0f5bd74be2401f59',
#   '6406369b716fd81934d77c763c032800'],
#  '8270587f50336280d43417aa650555ed': ['ea7bbc39d4a48a930ceb42c973fab232',
#   'c95bc2ea979f6156a978ab41fc23bda8',
#   'd11a5ac8df500a134e3ae5b802417f1a'],
#  '82aba308414f5f323933265b8afcc279': ['d39007ac7f210a50de0a724242a63c8b',
#   'f8c3976353d43ef02c5be1abf0f8abe0'],
#  '82c184570abf789f81412a3957c6abfc': ['405e9ede8ecbc4706f9b64dca3a12c03',
#   '4171cced6a77148df5a2e40725d7b6d6',
#   '13982201358a7f69c0d5ba08d1649a0b',
#   'bd58c3aaf28406ac1ada9a4da85b1ece',
#   '8b209323944a39ad917c21c18c137198',
#   'd7c7a9efc3713e00dd10728c5eaab1f0',
#   '91133ecbcd3317c43435b2f37d50f2e7'],
#  '82dd4124cff225390433274100083f6b': ['c0d9a5ecfa44a9d036180e94395cd1a0',
#   'fc9345e5e6ecf4f22a5ef09052967b6b',
#   '328c7201e8770b384585b2bcc266374a',
#   '3672f1aca8056386204e317c1027cfff'],
#  '82e0e5b47583ba05f73d022faf43efbf': ['7a02b3a3482deee2e3bbd1a3ba89b163',
#   'e6cb01b7e7558e0015f1a9c3e8930280',
#   '9cab87e4adff5699c51d47f317f86227',
#   '132a1b52777bc1f6e67ecbbe6690e3d7',
#   'a6f28a4940a4b16780ac521ba3c1abdc',
#   '17084521b6f84589ce4e1021e0b474c4'],
#  '830a590eacfe9494283700c6359581b0': ['98d62049057f433b21f8a05c18d2ba09',
#   'd20d7283e393834687a9558d43e99aa5',
#   '074eb3e0672995603c12837f08931d44',
#   'd143ae81f6868dbf0413f2baa4562478',
#   '134397ff0a239e0215625a469c658bef'],
#  '83257e48ab54dc2aa8f6e855745a6399': ['2d42cfbf854891697c0a52c9cca11857',
#   '31265248a2cc5eff1dd3472916d4f242',
#   'df2de568655c99628b35b6c3b9f7ca2d',
#   'f439f78804ed2721e6686a43de37b994'],
#  '832f5d5103984aaef2178df40f7fd624': ['a47107bc26cbdd3ee4bf44468fa063db',
#   '4327516020f617c36db614a4ede9c27f',
#   '0cc22bb621cc02661cc0607d58fc0079',
#   'b7e3365e9f7cb0d6c96641c28ed9034d',
#   '06304934220301845b6e447c5078c3d2'],
#  '8346f9f85456477db656acdfbb1259f1': ['4b1552aec77fa2ece7249100511d67b5',
#   '19e6b8a9bb9bfda25df0d75da656cd1a',
#   'af09404e6bb5d95a7ee278acf3ea8c2d',
#   '923656d905513de350bd66166a9dd799',
#   'e6d55c0876759c29eae3a9bf66f1f9cc',
#   '4cdac0499f0c4dfc9ae385e12c44fedd',
#   'c2ab33671a5352f865413a84b884264a'],
#  '838005bdf3e49dce29f73fa7e49a8e38': ['dcc767f904a235a3fbf2649671dc657a',
#   '90c318d5122481082fb9cdaf5b8df4ba',
#   '6c764e434834b573af9cac373904c462',
#   'fe1bc502087ce27e5f544f9cae6dbd6f',
#   'fc402836e29d64a4fea9b5c7a6b3507c',
#   'e936e05e631994e18e39fcc8d42ebc3b'],
#  '83a48a1c3d94e3b97ea79eef5187f63e': ['1c5924cdad20ad79e2e72a4d4f09f5fb',
#   '0f9fb763806af1c01bda375190b30136',
#   'dedf375144a2b15ca505f3cebe056ad1'],
#  '83b6cc16457ac48a1f069b9c6ee33358': ['a1825e06bb98de603140ef7eb6aadf8a',
#   '93e419ccf7c80040ea0849a1db9bcd0a',
#   'fc6aa7a713343b5dc8a73b1d1fdce9c3'],
#  '83cdffb59508906a08d51346662dcad6': ['37e683e383e75a1f3b56f471f0ecb035',
#   '929617dd97931e62a07963f87fb18120'],
#  '841bc953f1b56fc06ab9b57c2a0b437a': ['b8f894a7e1199cecb124fcc8ec1da209',
#   '73887c2709f6b1d7b7672c04c1558f08',
#   '237523854d2d00decb3ec30d8850c386',
#   'ea3fc8d2765d8514f54696e6b08d3ef9'],
#  '843b7c2e116e7d0e0f77022844e6c87b': ['9504289d381c86772a5edcea538405be'],
#  '8485b7d7758ed4963f79b88434b788c6': ['26966a9d226a87055962afeeafc0ddee',
#   'a5862c360ead6d15c3e1a8758ca6f063',
#   '370c605a29295fb285a1248ba8a5a667',
#   '3940f1f0c8bd445edac6bbcb7769ab18',
#   '26e06f6f0bc1b55ae5ba5d461a7304be',
#   '570607ba6bf0d576262ed5256dcf8270',
#   'c3ef12ae56b20436c37cb4e41f0872f7'],
#  '84da72655e6289d4095ee3cc2f16621a': ['9598482af085003ee505b93a11710bb2',
#   '72d2966d083dd93eec7fe6026e730357',
#   'a50cdfde7dbd9c607d8d0ec4846e0836'],
#  '84e0c8e592ecd17828a2ee889bd8683e': ['0f59f8b209799e9de759c0455f58130d',
#   '60de740d1e59fa61389dcb4b5ccb885a',
#   '78ab15573160d524e80bd6619367921a',
#   '9ac638de61d3c50fd86eef4a6d209d24',
#   '99a7d5d74c0e2130791ece0372cd61c5'],
#  '8571297fdedfd3de833c96b542f6f1c9': ['7c78209a648f13a155b9d6f6e3015270'],
#  '8589e8bc73f07552590ad0d32880fc2b': ['60b53373691fb36aa8546dc42ff16690',
#   'af91198d11ba99ba10848449af5e3d7b',
#   'a0e82c15c1e4bf4ae3b192cf9e8c7ed7'],
#  '85911347a76501f59db6cba27491c8f9': ['ed92a7943d36c5afd1327c9333f6e326'],
#  '8609c847a20a88de60f55b853f7efc28': ['5276b82be314b75e34f2e6f75e4e69cc',
#   'a27a6184b1f48636f13a48945435eedf',
#   '5526765a25056e561fe38189c00bb8ee'],
#  '865c59e2c3ce143f90ea5e3e8b6465ff': ['fee86429adb1d37b3cec378e9225d38b',
#   'd5516c176f0e2cff57134206758336a9',
#   '9d8723cc6bfb538ffcd3ea63d50ba131',
#   '0d3ecc4cc04558e450136bce524a9c20',
#   '833d0008fc6ef341a4b37f59c5695673'],
#  ...}

# %% [markdown]
# # BM25 (gensim)

# %%
from gensim.corpora import Dictionary
from gensim.models import TfidfModel, OkapiBM25Model
from gensim.similarities import SparseMatrixSimilarity
import numpy as np
corpus = [
    "今天 很开心",
    "明天 也 很开心",
    "Python is a programming language"
]
corpus = [doc.lower().split() for doc in corpus]#[["Hello", "world"], ["bar", "bar"], ["foo", "bar"]]
dictionary = Dictionary(corpus)
bm25_model = OkapiBM25Model(dictionary=dictionary)
bm25_corpus = bm25_model[list(map(dictionary.doc2bow, corpus))]
bm25_index = SparseMatrixSimilarity(bm25_corpus, num_docs=len(corpus), num_terms=len(dictionary),
                                   normalize_queries=False, normalize_documents=False)
query = ["learn", '今天']
tfidf_model = TfidfModel(dictionary=dictionary, smartirs='bnn')  # Enforce binary weighting of queries
tfidf_query = tfidf_model[dictionary.doc2bow(query)]
similarities = bm25_index[tfidf_query]
print(similarities)
best_document = corpus[np.argmax(similarities)]
" ".join(best_document)
# Out:
# [0.62295806 0.         0.        ]
# '今天 很开心'

# %%
corpus = [
    jieba.lcut(x['text']) for x in data['corpus']
]
dictionary = Dictionary(corpus)
bm25_model = OkapiBM25Model(dictionary=dictionary)
bm25_corpus = bm25_model[list(map(dictionary.doc2bow, corpus))]
bm25_index = SparseMatrixSimilarity(bm25_corpus, num_docs=len(corpus), num_terms=len(dictionary),
                                   normalize_queries=False, normalize_documents=False)

# %%
# https://radimrehurek.com/gensim/models/tfidfmodel.html
tfidf_model = TfidfModel(dictionary=dictionary, smartirs='afc')

# %%
# %%time
query = '请注意识别,谨防上当受骗!'
query = jieba.lcut(query)
tfidf_query = tfidf_model[dictionary.doc2bow(query)]
similarities = bm25_index[tfidf_query]

best_document = corpus[np.argmax(similarities)]
" ".join(best_document)
# Out:
# CPU times: total: 0 ns
# Wall time: 18.4 ms
# '该 经验 图片 、 文字 中 可能 存在 外站 链接 或 电话号码 等 , 请 注意 识别 , 谨防 上当受骗 ! 百度 经验 : jingyan . baidu . com 在 之前 win7 的 设置 中 大部分 操作 都 是 在 控制面板 中 完成 的 , 可是 在 新 的 win10 系统 中 却 发现 控制面板 很难 找 了 , 那么 在 哪里 能 找到 呢 ? 让 我 来 告诉 你 吧 ~ 百度 经验 : jingyan . baidu . com 百度 经验 : jingyan . baidu . com1   打开 开始菜单 , 点击 所有 应用   步骤 阅读   2   找到 windows 系统 , 点击 打开 下级菜单   步骤 阅读   3   在 当中 找到 控制面板 点击 打开 即可   步骤 阅读   END 百度 经验 : jingyan . baidu . com'

# %%
qrels_dict = {x['qid']: x['pid'] for x in qrels["dev"]}
pid_array = np.array([x['id'] for x in data['corpus']])

# %%
# 2. 直接导入rank_bm25模型
from rank_bm25 import BM25Okapi
tokenized_corpus = [jieba.lcut(x["text"]) for x in data["corpus"]]
bm25 = BM25Okapi(tokenized_corpus)

# tfidf_model=TfidfModel(dictionary=dictionary,smartirs='afc')

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query = jieba.lcut(query_data['text'])
    query_qid = query_data['id']
    query_pids = qrels_dict[query_qid]
    
    # tfidf_query = tfidf_model[dictionary.doc2bow(query)]
    similarities = np.array(bm25.get_scores(query))
    # similarities=bm25_index[tfidf_query]
    top_results = similarities.argsort()[::-1][:topn]
    top_results = [data['corpus'][int(x)]['id'] for x in top_results]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [03:48<00:00,  8.75it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.3449331376092457, 0.3423558128037693)

# %% [markdown]
# # BM25 (rank_bm25)

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "Hello there good man!",
    "It is quite windy in London",
    "How is the weather today?"
]

tokenized_corpus = [doc.split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

query = "windy London"
tokenized_query = query.split(" ")
bm25.get_scores(tokenized_query)
# Out:
# array([0.        , 0.93729472, 0.        ])

# %%
corpus = [jieba.lcut(x['text']) for x in data['corpus']]
bm25 = BM25Okapi(corpus)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.539 seconds.
# Prefix dict has been built successfully.

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query = jieba.lcut(query_data['text'])
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = np.array(bm25.get_scores(query))
    top_results = similarities.argsort()[::-1][:topn]
    top_results = [data['corpus'][int(x)]['id'] for x in top_results]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [06:26<00:00,  5.17it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.7077681714845733, 0.3301973263950749)

# %% [markdown]
# # M3E

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('./hugging-face-model/moka-ai/m3e-small/')

#Our sentences we like to encode
sentences = [
    '* Moka 此文本嵌入模型由 MokaAI 训练并开源，训练脚本使用 uniem',
    '* Massive 此文本嵌入模型通过**千万级**的中文句对数据集进行训练',
    '* Mixed 此文本嵌入模型支持中英双语的同质文本相似度计算，异质文本检索等功能，未来还会支持代码检索，ALL in one'
]

#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

#Print the embeddings
for sentence, embedding in zip(sentences, embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding.shape)
    print("")
# Out:
# Sentence: * Moka 此文本嵌入模型由 MokaAI 训练并开源，训练脚本使用 uniem
# Embedding: (512,)
#
# Sentence: * Massive 此文本嵌入模型通过**千万级**的中文句对数据集进行训练
# Embedding: (512,)
#
# Sentence: * Mixed 此文本嵌入模型支持中英双语的同质文本相似度计算，异质文本检索等功能，未来还会支持代码检索，ALL in one
# Embedding: (512,)

# %%
corpus = [x['text'] for x in data['corpus']][:]
embeddings = model.encode(corpus, normalize_embeddings=True)

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query_feat = model.encode(query_data['text'], normalize_embeddings=True)
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = query_feat.dot(embeddings.T)
    top_results = similarities.argsort()[::-1][:topn]
    top_results = [data['corpus'][int(x)]['id'] for x in top_results]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [01:32<00:00, 21.68it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.7614511933399406, 0.27839499502211373)

# %% [markdown]
# # BGE

# %%
from sentence_transformers import SentenceTransformer
sentences_1 = ["样例数据-1", "样例数据-2"]
sentences_2 = ["样例数据-3", "样例数据-4"]
model = SentenceTransformer('./hugging-face-model/BAAI/bge-small-zh-v1.5/')
embeddings_1 = model.encode(sentences_1, normalize_embeddings=True)
embeddings_2 = model.encode(sentences_2, normalize_embeddings=True)
similarity = embeddings_1 @ embeddings_2.T
print(similarity)
# Out:
# [[0.86921406 0.8665448 ]
#  [0.899487   0.8784326 ]]

# %%
corpus = [x['text'] for x in data['corpus']][:]
embeddings = model.encode(corpus, normalize_embeddings=True)

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query_feat = model.encode(query_data['text'], normalize_embeddings=True)
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = query_feat.dot(embeddings.T)
    top_results = similarities.argsort()[::-1][:topn]
    top_results = [data['corpus'][int(x)]['id'] for x in top_results]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [01:33<00:00, 21.35it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.8629532887126161, 0.221727574464936)

# %% [markdown]
# # BGE with ReRank

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('./hugging-face-model/BAAI/bge-reranker-base/')
rerank_model = AutoModelForSequenceClassification.from_pretrained('./hugging-face-model/BAAI/bge-reranker-base/')
rerank_model.cuda()
rerank_model.eval()

pairs = [['我很开心', '我很沮丧'], ['我很开心', '我很快乐']]
with torch.no_grad():
    inputs = tokenizer(pairs, padding=True, truncation=True, return_tensors='pt', max_length=512)
    inputs = {key: inputs[key].cuda() for key in inputs.keys()}
    scores = rerank_model(**inputs, return_dict=True).logits.view(-1, ).float()
    print(scores)
# Out:
# tensor([-6.0319,  8.9878], device='cuda:0')

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query_feat = model.encode(query_data['text'], normalize_embeddings=True)
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = query_feat.dot(embeddings.T)
    top_results = similarities.argsort()[::-1][:topn]

    pairs = []
    for xi in top_results:
        pairs.append([query_data['text'], corpus[xi]])

    inputs = tokenizer(pairs, padding=True, truncation=True, return_tensors='pt', max_length=512)
    with torch.no_grad():
        inputs = {key: inputs[key].cuda() for key in inputs.keys()}
        scores = rerank_model(**inputs, return_dict=True).logits.view(-1, ).float()

    top_results = np.array(top_results)
    rerank_result = top_results[scores.cpu().data.numpy().argsort()[::-1]]
    
    top_results = [data['corpus'][int(x)]['id'] for x in rerank_result]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [27:28<00:00,  1.21it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.9160629142553329, 0.19732814717552222)

# %% [markdown]
# # BCEmbedding（有道）

# %%
from sentence_transformers import SentenceTransformer

# list of sentences
sentences = ['sentence_0', 'sentence_1', ...]

# init embedding model
model = SentenceTransformer("./hugging-face-model/maidalun1020/bce-embedding-base_v1")

# set max_length to 512 to avoid an error.
model.max_seq_length = 512

# extract embeddings
embeddings = model.encode(sentences, normalize_embeddings=True)

# %%
corpus = [x['text'] for x in data['corpus']][:]
embeddings = model.encode(corpus, normalize_embeddings=True)

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query_feat = model.encode(query_data['text'], normalize_embeddings=True)
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = query_feat.dot(embeddings.T)
    top_results = similarities.argsort()[::-1][:topn]
    top_results = [data['corpus'][int(x)]['id'] for x in top_results]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [02:06<00:00, 15.76it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.8436841563775636, 0.22071295950607342)

# %% [markdown]
# # BCEmbedding with ReRank

# %%
from sentence_transformers import CrossEncoder

# init reranker model
rerank_model = CrossEncoder('./hugging-face-model/maidalun1020/bce-reranker-base_v1', max_length=512)

pairs = [['我很开心', '我很沮丧'], ['我很开心', '我很快乐']]
scores = rerank_model.predict(pairs)

# %%
query_feats = model.encode([x['text'] for x in data['queries']], normalize_embeddings=True)

# %%
query_feat.dot(embeddings.T)
# Out:
# array([0.17447105, 0.19908555, 0.15706639, ..., 0.25002584, 0.2793538 ,
#        0.28668842], dtype=float32)

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query_feat = model.encode(query_data['text'], normalize_embeddings=True)
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = query_feat.dot(embeddings.T)
    top_results = similarities.argsort()[::-1][:topn]

    pairs = []
    for xi in top_results:
        pairs.append([query_data['text'], corpus[xi]])

    with torch.no_grad():
        scores = rerank_model.predict(pairs)

    top_results = np.array(top_results)
    rerank_result = top_results[scores.argsort()[::-1]]
    
    top_results = [data['corpus'][int(x)]['id'] for x in rerank_result]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [27:58<00:00,  1.19it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.46059702380952383, 0.3968857660785824)

# %% [markdown]
# # GTE

# %%
from sentence_transformers import SentenceTransformer
sentences_1 = ["样例数据-1", "样例数据-2"]
sentences_2 = ["样例数据-3", "样例数据-4"]
model = SentenceTransformer('./hugging-face-model/thenlper/gte-small-zh')
embeddings_1 = model.encode(sentences_1, normalize_embeddings=True)
embeddings_2 = model.encode(sentences_2, normalize_embeddings=True)
similarity = embeddings_1 @ embeddings_2.T
print(similarity)
# Out:
# [[0.962006   0.95747596]
#  [0.95021254 0.94485617]]

# %%
corpus = [x['text'] for x in data['corpus']][:]
embeddings = model.encode(corpus, normalize_embeddings=True)

# %%
topn = 30
query_ndcg_score = []
for query_data in tqdm(data['queries']):
    query_feat = model.encode(query_data['text'], normalize_embeddings=True)
    query_qid = query_data['id']
    query_pids = qrels[query_qid]
    
    similarities = query_feat.dot(embeddings.T)
    top_results = similarities.argsort()[::-1][:topn]
    top_results = [data['corpus'][int(x)]['id'] for x in top_results]
    true_relevance  = [[x in query_pids for x in top_results]]
    scores = [list(similarities[similarities.argsort()[::-1][:topn]])]

    query_ndcg_score.append(ndcg_score(true_relevance, scores))
# Out:
# 100%|██████████| 2000/2000 [01:58<00:00, 16.90it/s]

# %%
np.mean(query_ndcg_score), np.std(query_ndcg_score)
# Out:
# (0.8563148126485296, 0.21721973465173638)
